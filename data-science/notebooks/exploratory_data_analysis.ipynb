# %% [markdown]
# # Proyek Capstone Tim Data Science: Mathematics Student Performance Dataset
# - **ID Tim**: CC26-PSU362
# - **Anggota Tim**:
#     1. Farhan Nawwafal Pramudia - CDCC237D6Y2155
#     2. Suyeni Meisyalena - CDCC277D6X0986

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis
# - **Pertanyaan 1:** Bab (chapter) Matematika kelas 7 mana yang mencatatkan rata-rata skor (score) assessment terendah dari seluruh siswa selama tahun 2026?
# - **Pertanyaan 2:** Bagaimana persentase distribusi tingkat kompetensi siswa (beginner, intermediate, advanced) pada seluruh sub-bab secara kumulatif selama tahun 2026?
# - **Pertanyaan 3:** Bab (chapter) mana yang memiliki tingkat penyelesaian dengan status 'done' tertinggi dibandingkan dengan total bab yang diambil oleh siswa pada tahun 2026?
# - **Pertanyaan 4:** Tampilkan 5 sub-bab yang paling banyak membuat siswa stuck, memiliki status 'in-progress' dalam durasi yang lama selama tahun 2026?
# - **Pertanyaan 5:** Bagaimana perbandingan rata-rata skor siswa pada assessment bertipe 'placement' (tes diagnostik/awal) dibandingkan dengan rata-rata skor pada tipe 'exam' di setiap bab (chapter) selama tahun 2026?

# %% [markdown]
# ## Menyiapkan Library

# %%
import random
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load users_df

# %%
users_df = pd.read_csv('../data/users.csv')
users_df.head()
# Out:
#   student_id            name  birth_date   role                         email  \
# 0      S0001   Endah Gunawan  2014-11-07  siswa   endah.gunawan7522@gmail.com
# 1      S0002   Fitri Ginting  2014-07-02  siswa   fitri.ginting7171@gmail.com
# 2      S0003   Hafiz Purnama  2014-04-27  siswa   hafiz.purnama7169@gmail.com
# 3      S0004  Qori Wulandari  2013-10-19  siswa  qori.wulandari6789@gmail.com
# 4      S0005      Oki Kusuma  2013-11-20  siswa      oki.kusuma6301@gmail.com
#
#      password           created_at           updated_at
# 0  gglfOR3Poo  2026-04-10 20:36:13  2026-04-24 06:00:12
# 1  8BRc5HE5vg  2026-04-20 03:52:08  2026-04-20 03:52:08
# 2  EDddm17eCd  2026-04-18 13:40:46  2026-04-24 16:39:25
# 3  fiJdGLJ3Pa  2026-02-14 06:15:12  2026-03-08 22:55:37
# 4  s7ZqmJVtwL  2026-03-02 22:09:36  2026-03-02 22:09:36

# %% [markdown]
# #### Load chapters_df

# %%
chapters_df = pd.read_csv('../data/chapters.csv')
chapters_df.head()
# Out:
#         id               name  total_subchapter           created_at  \
# 0  CT00001     Bilangan Bulat                 3  2026-01-01 00:00:00
# 1  CT00002  Bilangan Rasional                 3  2026-01-01 00:00:00
# 2  CT00003              Rasio                 3  2026-01-01 00:00:00
# 3  CT00004     Bentuk Aljabar                 3  2026-01-01 00:00:00
# 4  CT00005       Kesebangunan                 3  2026-01-01 00:00:00
#
#             updated_at
# 0  2026-01-01 00:00:00
# 1  2026-01-01 00:00:00
# 2  2026-01-01 00:00:00
# 3  2026-01-01 00:00:00
# 4  2026-01-01 00:00:00

# %% [markdown]
# #### Load subchapters_df

# %%
subchapters_df = pd.read_csv('../data/subchapters.csv')
subchapters_df.head()
# Out:
#          id chapter_id                             name           created_at  \
# 0  SCT00001    CT00001          Memahami Bilangan Bulat  2026-01-01 00:00:00
# 1  SCT00002    CT00001    Operasi Hitung Bilangan Bulat  2026-01-01 00:00:00
# 2  SCT00003    CT00001            Faktor Bilangan Bulat  2026-01-01 00:00:00
# 3  SCT00004    CT00002     Di Antara Dua Bilangan Bulat  2026-01-01 00:00:00
# 4  SCT00005    CT00002  Membandingkan Bilangan Rasional  2026-01-01 00:00:00
#
#             updated_at
# 0  2026-01-01 00:00:00
# 1  2026-01-01 00:00:00
# 2  2026-01-01 00:00:00
# 3  2026-01-01 00:00:00
# 4  2026-01-01 00:00:00

# %% [markdown]
# #### Load chapters_taken_df

# %%
chapters_taken_df = pd.read_csv('../data/chapters_taken.csv')
chapters_taken_df.head()
# Out:
#          id user_id chapter_id         created_at_x           updated_at  \
# 0  CHT00001   S0331    CT00002  2025-01-16 00:14:42  2026-04-27 23:18:52
# 1  CHT00002   S0242    CT00002  2024-07-20 18:18:07  2026-04-06 12:52:29
# 2  CHT00003   S0181    CT00006  2025-01-14 04:34:27  2026-04-12 00:35:07
# 3  CHT00004   S0145    CT00003  2025-02-13 19:24:19  2026-04-27 23:18:52
# 4  CHT00005   S0116    CT00006  2024-09-17 06:35:49  2026-04-20 18:32:43
#
#             created_at
# 0  2026-04-25 03:10:15
# 1  2026-04-01 19:01:29
# 2  2026-04-07 06:44:07
# 3  2026-04-26 22:45:20
# 4  2026-04-16 00:41:43

# %% [markdown]
# #### Load assessments_df

# %%
assessments_df = pd.read_csv('../data/assessments.csv')
assessments_df.head()
# Out:
#         id chapter_taken_id subchapter_id         title       type  \
# 0  AS00001         CHT01062      SCT00003  Assessment 1       exam
# 1  AS00002         CHT00314      SCT00009  Assessment 2       quiz
# 2  AS00003         CHT00935      SCT00007  Assessment 3       exam
# 3  AS00004         CHT00015      SCT00020  Assessment 4  placement
# 4  AS00005         CHT00800      SCT00004  Assessment 5  placement
#
#    correct_answer           created_at           updated_at
# 0            20.0  2026-04-19 06:00:27  2026-04-19 06:47:27
# 1            18.0  2026-04-27 16:47:57  2026-04-27 17:34:57
# 2            24.0  2026-04-27 22:44:06  2026-04-27 23:18:52
# 3             6.0  2026-04-25 13:55:29  2026-04-25 14:42:29
# 4            19.0  2026-04-10 05:05:48  2026-04-10 05:52:48

# %% [markdown]
# #### Load user_attempts_df

# %%
user_attempts_df = pd.read_csv('../data/user_attempts.csv')
user_attempts_df.head()
# Out:
#         id user_id assessment_id  score         completed_at  \
# 0  UA00001   S9999       AS00193  34.80  2026-04-20 21:50:12
# 1  UA00002   S0180       AS00112  56.55  2026-04-25 09:26:43
# 2  UA00003   S0362       AS00056  86.55  2026-04-27 06:19:37
# 3  UA00004   S0702       AS00180  14.12  2026-04-27 23:18:52
# 4  UA00005   S0585       AS00153   8.11  2026-04-27 21:36:30
#
#             created_at           updated_at
# 0  2026-04-20 21:08:12  2026-04-20 21:54:12
# 1  2026-04-25 08:44:43  2026-04-25 09:30:43
# 2  2026-04-27 05:37:37  2026-04-27 06:23:37
# 3  2026-04-27 23:04:12  2026-04-27 23:18:52
# 4  2026-04-27 20:54:30  2026-04-27 21:40:30

# %% [markdown]
# #### Load user_progress_df

# %%
user_progress_df = pd.read_csv('../data/user_progress.csv')
user_progress_df.head()
# Out:
#         id user_id subchapter_id chapter_taken_id current_level       status  \
# 0  UP00001   S0591      SCT00017         CHT00802      beginner  not started
# 1  UP00002   S0655      SCT00020         CHT00317      beginner         done
# 2  UP00002   S0655      SCT00020         CHT00317      beginner         done
# 3  UP00003   S0617      SCT00008         CHT00533  intermediate  not started
# 4  UP00004   S0966      SCT00001         CHT00638  intermediate         done
#
#             created_at           updated_at
# 0  2026-04-19 01:10:42  2026-04-20 01:27:42
# 1  2026-04-22 08:32:30  2026-04-23 08:49:30
# 2  2026-04-24 17:35:18  2026-04-25 17:52:18
# 3  2026-04-25 18:53:39  2026-04-26 19:10:39
# 4  2026-04-19 00:35:00  2026-04-20 00:52:00

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai data users_df

# %%
# Melihat struktur data
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  1000 non-null   object
#  1   name        990 non-null    object
#  2   birth_date  966 non-null    object
#  3   role        978 non-null    object
#  4   email       976 non-null    object
#  5   password    982 non-null    object
#  6   created_at  1000 non-null   object
#  7   updated_at  1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %% [markdown]
# **Steps to Take:**
# - Mengubah tipe data object pada kolom `birth_date`, `created_at` dan `updated_at` menjadi datetime
# - Handling missing value dengan mempertimbangkan konteks data

# %% [markdown]
# **Insights**:
# - Terdapat jumlah baris berbeda di setiap fitur. Hal ini menandakan bahwa `adanya missing value`.
# - Tipe data pada fitur `birth_date`, `created_at`, dan `updated_at` masih `object`. Tipe data ini masih kurang tepat, harusnya datetime.
# - Hal-hal ini akan ditangani di proses `cleaning data`

# %%
# Mengecek missing value
users_df.isna().sum()
# Out:
# student_id     0
# name          10
# birth_date    34
# role          22
# email         24
# password      18
# created_at     0
# updated_at     0
# dtype: int64

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights**:
# - Sesuai dengan penjelasan sebelumnya bahwa terdapat `missing value` pada beberapa fitur.
# - Hal ini akan diproses pada tahap `cleaning data`

# %%
# Mengecek jumlah duplikasi data
print(f'Jumlah duplikasi users_df: {users_df.duplicated().sum()}')
# Out:
# Jumlah duplikasi users_df: 0

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights**:
# - `users_df` tidak memiliki data duplikat. Berarti ini tidak perlu dibersihkan pada tahap `cleaning data`

# %%
# Mengecek deskriptif statistik
users_df.describe(include='all')
# Out:
#        student_id name  birth_date   role                        email  \
# count        1000  990         966    978                          976
# unique       1000  561         720      6                          976
# top         S0001  ???  2013-01-03  siswa  endah.gunawan7522@gmail.com
# freq            1   13           5    952                            1
#
#        password           created_at           updated_at
# count       982                 1000                 1000
# unique      975                 1000                 1000
# top         ???  2026-04-10 20:36:13  2026-04-24 06:00:12
# freq          8                    1                    1

# %% [markdown]
# **Steps to Take:**
# - Menggunakan salah satu teknik handling missing value, pada tahap cleaning data

# %% [markdown]
# **Insights**:
# - Karena banyak data kategorikal, maka tidak banyak informasi yang bisa didapatkan.
# - Yang bisa didapatkan adalah fitur `name`, `birth_date`, `role`, `gmail`, dan `password` itu tidak memiliki `count` yang sama dengan fitur `student_id`. Hal ini menandakan adanya `missing value`

# %% [markdown]
# #### Menilai data chapters_df

# %%
# Mengecek struktur data
chapters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                6 non-null      object
#  1   name              6 non-null      object
#  2   total_subchapter  6 non-null      int64
#  3   created_at        6 non-null      object
#  4   updated_at        6 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 372.0+ bytes

# %% [markdown]
# **Steps to Take:**
# - Mengubah tipe data object pada kolom `created_at` dan `updated_at` menjadi datetime

# %% [markdown]
# **Insight**:
# - Tidak ada `missing value`. Hal ini bisa dilihat pada jumlah baris di setiap fitur itu sama.
# - Hanya saja ada tipe data yang kurang tepat pada fitur `created_at` dan `updated_at`. Seharusnya tipe datanya `datetime`
# - Hal ini akan diproses pada tahap `cleaning data`

# %%
# Mengecek missing value
chapters_df.isna().sum()
# Out:
# id                  0
# name                0
# total_subchapter    0
# created_at          0
# updated_at          0
# dtype: int64

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insight**:
# - Terbukti bahwa `chapters_df` tidak memiliki `missing_value`

# %%
# Mengecek jumlah duplikasi data
print(f'Jumlah duplikasi data chapters_df: {chapters_df.duplicated().sum()}')
# Out:
# Jumlah duplikasi data chapters_df: 0

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights**:
# - Tidak ada duplikasi data juga pada `chapters_df`

# %%
# Mengecek deskriptif statistik
chapters_df.describe(include='all')
# Out:
#              id            name  total_subchapter           created_at  \
# count         6               6          6.000000                    6
# unique        6               6               NaN                    1
# top     CT00001  Bilangan Bulat               NaN  2026-01-01 00:00:00
# freq          1               1               NaN                    6
# mean        NaN             NaN          3.500000                  NaN
# std         NaN             NaN          1.224745                  NaN
# min         NaN             NaN          3.000000                  NaN
# 25%         NaN             NaN          3.000000                  NaN
# 50%         NaN             NaN          3.000000                  NaN
# 75%         NaN             NaN          3.000000                  NaN
# max         NaN             NaN          6.000000                  NaN
#
#                  updated_at
# count                     6
# unique                    1
# top     2026-01-01 00:00:00
# freq                      6
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights**:
# - Pada fitur `total_subchapter`, terdapat `min = 3` dan `max = 6`
# - Artinya, jumlah subbab yang paling minimal ialah 3 subbab dan paling banyak, 6 subbab.

# %% [markdown]
# #### Menilai data subchapters_df

# %%
# Mengecek struktur data
subchapters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          21 non-null     object
#  1   chapter_id  21 non-null     object
#  2   name        21 non-null     object
#  3   created_at  21 non-null     object
#  4   updated_at  21 non-null     object
# dtypes: object(5)
# memory usage: 972.0+ bytes

# %% [markdown]
# **Steps to Take:**
# - Mengubah tipe data object pada kolom `created_at` dan `updated_at` menjadi datetime

# %% [markdown]
# **Insights**:
# - `subchapters_df` juga memiliki jumlah baris yang sama di setiap fitur.
# - Artinya, ia `tidak memiliki missing value`.
# - Tetapi pada fitur `created_at` dan `updated_at` memiliki tipe data `object`. Seharusnya `datetime`. Hal ini akan diproses pada tahap `cleaning_data`

# %%
# Mengecek missing value
subchapters_df.isna().sum()
# Out:
# id            0
# chapter_id    0
# name          0
# created_at    0
# updated_at    0
# dtype: int64

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights**:
# - Terbukti bahwa tidak ada missing value

# %%
# Mengecek jumlah duplikasi data
print(f'Jumlah duplikasi data subchapters_df: {subchapters_df.duplicated().sum()}')
# Out:
# Jumlah duplikasi data subchapters_df: 0

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights**:
# - Tidak ada duplikasi data pada `subchapters_df`

# %%
# Mengecek deskriptif statistik
subchapters_df.describe(include='all')
# Out:
#               id chapter_id                     name           created_at  \
# count         21         21                       21                   21
# unique        21          6                       21                    1
# top     SCT00001    CT00006  Memahami Bilangan Bulat  2026-01-01 00:00:00
# freq           1          6                        1                   21
#
#                  updated_at
# count                    21
# unique                    1
# top     2026-01-01 00:00:00
# freq                     21

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights**:
# - Pada baris count di setiap kolom, memiliki nilai yang sama. Artinya tidak ada indikasi missing value

# %% [markdown]
# #### Menilai data chapters_taken_df

# %%
# Mengecek struktur data
chapters_taken_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1220 non-null   object
#  1   user_id       1220 non-null   object
#  2   chapter_id    1220 non-null   object
#  3   created_at_x  1220 non-null   object
#  4   updated_at    1220 non-null   object
#  5   created_at    1220 non-null   object
# dtypes: object(6)
# memory usage: 57.3+ KB

# %% [markdown]
# **Steps to Take:**
# - Menghapus kolom `created_at_x` pada tahap cleaning data
# - Mengubah tipe data object pada kolom `created_at` dan `updated_at` menjadi datetime

# %% [markdown]
# **Insights**:
# - Terdapat anomali fitur, yaitu `created_at_x`. Hal ini akan dihapus pada tahap `cleaning data`
# - Pada fitur `created_at` dan `updated_at`, tipe datanya masih `object`. Pada tahap `cleaning data` akan diubah menjadi `datetime`
# - Jumlah data di setiap fitur sama, artinya data ini `tidak memiliki missing value`

# %%
# Mengecek missing value
chapters_taken_df.isna().sum()
# Out:
# id              0
# user_id         0
# chapter_id      0
# created_at_x    0
# updated_at      0
# created_at      0
# dtype: int64

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights:**
# - Terbukti bahwa `tidak ada missing value`

# %%
# Mengecek jumlah duplikasi data
print(f'Jumlah duplikasi data chapters_taken_df: {chapters_taken_df.duplicated().sum()}')
# Out:
# Jumlah duplikasi data chapters_taken_df: 0

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights**:
# - Tidak ada jumlah duplikasi data

# %%
# Mengecek deskriptif statistik
chapters_taken_df.describe(include='all')
# Out:
#               id user_id chapter_id         created_at_x           updated_at  \
# count       1220    1220       1220                 1220                 1220
# unique      1200     701          6                 1200                  949
# top     CHT00487   S0582    CT00004  2024-10-06 02:22:08  2026-04-27 23:18:52
# freq           2       8        216                    2                  272
#
#                  created_at
# count                  1220
# unique                 1220
# top     2026-04-25 03:10:15
# freq                      1

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights**:
# - Pada baris count di seluruh kolom, semua nya memiliki nilai yang sama, yaitu 1220.
# - Artinya, semua kolom ini tidak ada indikasi missing value

# %% [markdown]
# #### Menilai data assessments_df

# %%
# Mengecek struktur data
assessments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                206 non-null    object
#  1   chapter_taken_id  206 non-null    object
#  2   subchapter_id     206 non-null    object
#  3   title             206 non-null    object
#  4   type              206 non-null    object
#  5   correct_answer    195 non-null    float64
#  6   created_at        206 non-null    object
#  7   updated_at        206 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 13.0+ KB

# %% [markdown]
# **Steps to Take:**
# - Handle missing value pada kolom correct_answer
# - Mengubah tipe data object pada kolom `created_at` dan `updated_at` menjadi datetime

# %% [markdown]
# **Insights:**
# - Pada fitur `correct_answer`, ia memiliki jumlah baris berbeda dibanding dengan fitur lainnya
# - Artinya, fitur itu memiliki `missing value`
# - Pada tipe data `created_at` dan `updated_at`, tipe datanya akan diubah ke `datetime`

# %%
# Mengecek missing value
assessments_df.isna().sum()
# Out:
# id                   0
# chapter_taken_id     0
# subchapter_id        0
# title                0
# type                 0
# correct_answer      11
# created_at           0
# updated_at           0
# dtype: int64

# %% [markdown]
# **Steps to Take:**
# - Handle missing value pada kolom correct_answer

# %% [markdown]
# **Insights:**
# - Terbukti bahwa kolom correct_answer memiliki missing value sebanyak 11 data

# %%
# Mengecek jumlah duplikasi data
print(f'Jumlah duplikasi data assessments_df: {assessments_df.duplicated().sum()}')
# Out:
# Jumlah duplikasi data assessments_df: 0

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights:**
# - Tidak ada duplikasi data pada data assessments_df

# %%
# Mengecek deskriptif statistik
assessments_df.describe(include='all')
# Out:
#              id chapter_taken_id subchapter_id           title       type  \
# count       206              206           206             206        206
# unique      200              186            21             200          4
# top     AS00164         CHT00952      SCT00009  Assessment 164  placement
# freq          2                2            17               2         74
# mean        NaN              NaN           NaN             NaN        NaN
# std         NaN              NaN           NaN             NaN        NaN
# min         NaN              NaN           NaN             NaN        NaN
# 25%         NaN              NaN           NaN             NaN        NaN
# 50%         NaN              NaN           NaN             NaN        NaN
# 75%         NaN              NaN           NaN             NaN        NaN
# max         NaN              NaN           NaN             NaN        NaN
#
#         correct_answer           created_at           updated_at
# count       195.000000                  206                  206
# unique             NaN                  206                  201
# top                NaN  2026-04-19 06:00:27  2026-04-27 23:18:52
# freq               NaN                    1                    6
# mean         15.446154                  NaN                  NaN
# std           6.179524                  NaN                  NaN
# min           5.000000                  NaN                  NaN
# 25%          10.000000                  NaN                  NaN
# 50%          16.000000                  NaN                  NaN
# 75%          21.000000                  NaN                  NaN
# max          25.000000                  NaN                  NaN

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights:**
# - Tidak ada

# %% [markdown]
# #### Menilai data user_attempts_df

# %%
# Mengecek struktur data
user_attempts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2053 entries, 0 to 2052
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2053 non-null   object
#  1   user_id        2053 non-null   object
#  2   assessment_id  2053 non-null   object
#  3   score          2053 non-null   float64
#  4   completed_at   2053 non-null   object
#  5   created_at     2053 non-null   object
#  6   updated_at     2053 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 112.4+ KB

# %% [markdown]
# **Steps to Take:**
# - Mengubah tipe data object pada kolom `created_at` dan `updated_at` menjadi datetime

# %% [markdown]
# **Insights:**
# - Semua kolom memiliki jumlah baris yang sama. Artinya data user_attempts_df ini tidak memiliki indikasi missing value
# - Tipe data untuk kolom `created_at` dan `updated_at` masih object. Seharusnya ini datetime. Hal ini akan ditangani di tahap cleaning data

# %%
# Mengecek missing value
user_attempts_df.isna().sum()
# Out:
# id               0
# user_id          0
# assessment_id    0
# score            0
# completed_at     0
# created_at       0
# updated_at       0
# dtype: int64

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights:**
# - Terbukti bahwa data user_attempts_df tidak memiliki missing value

# %%
# Mengecek jumlah duplikasi data
print(f'Jumlah duplikasi data user_attempts_df: {user_attempts_df.duplicated().sum()}')
# Out:
# Jumlah duplikasi data user_attempts_df: 0

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights:**
# - Tidak ada duplikasi data

# %%
# Mengecek deskriptif statistik
user_attempts_df.describe(include='all')
# Out:
#              id user_id assessment_id        score         completed_at  \
# count      2053    2053          2053  2053.000000                 2053
# unique     2000     873           200          NaN                 1927
# top     UA01001   S0128       AS00169          NaN  2026-04-27 23:18:52
# freq          2       8            24          NaN                  124
# mean        NaN     NaN           NaN    53.983176                  NaN
# std         NaN     NaN           NaN    75.231112                  NaN
# min         NaN     NaN           NaN   -50.000000                  NaN
# 25%         NaN     NaN           NaN    25.420000                  NaN
# 50%         NaN     NaN           NaN    49.020000                  NaN
# 75%         NaN     NaN           NaN    73.790000                  NaN
# max         NaN     NaN           NaN   999.000000                  NaN
#
#                  created_at           updated_at
# count                  2053                 2053
# unique                 2045                 1919
# top     2026-04-27 23:18:14  2026-04-27 23:18:52
# freq                      2                  132
# mean                    NaN                  NaN
# std                     NaN                  NaN
# min                     NaN                  NaN
# 25%                     NaN                  NaN
# 50%                     NaN                  NaN
# 75%                     NaN                  NaN
# max                     NaN                  NaN

# %% [markdown]
# **Steps to Take:**
# - Handling invalid value pada kolom `score`

# %% [markdown]
# **Insights:**
# - Pada baris min kolom score, terdapat nilai -50. Hal ini perlu ditangani karena termasuk `invalid value`
# - Pada baris max kolom score, terdapat nilai 999. Hal ini perlu ditangani karena termasuk `invalid value`
# - Kedua hal ini akan ditangani pada tahap cleaning data

# %% [markdown]
# #### Menilai data user_progress_df

# %%
# Mengecek struktur data
user_progress_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1552 non-null   object
#  1   user_id           1552 non-null   object
#  2   subchapter_id     1552 non-null   object
#  3   chapter_taken_id  1552 non-null   object
#  4   current_level     1476 non-null   object
#  5   status            1552 non-null   object
#  6   created_at        1552 non-null   object
#  7   updated_at        1552 non-null   object
# dtypes: object(8)
# memory usage: 97.1+ KB

# %% [markdown]
# **Steps to Take:**
# - Handling missing value pada kolom `current_level`
# - Mengubah tipe data object pada kolom `created_at` dan `updated_at` menjadi datetime

# %% [markdown]
# **Insights:**
# - Pada kolom `current_level` terdapat jumlah baris berbeda dengan kolom lainnya. Hal ini menandakan adanya indikasi missing value
# - Pada kolom `created_at` dan `updated_at` masih memiliki tipe data object. Ini harus diubah menjadi datetime
# - Semua hal di atas, akan dilakukan pada tahap cleaning data

# %%
# Mengecek missing value
user_progress_df.isna().sum()
# Out:
# id                   0
# user_id              0
# subchapter_id        0
# chapter_taken_id     0
# current_level       76
# status               0
# created_at           0
# updated_at           0
# dtype: int64

# %% [markdown]
# **Steps to Take:**
# - Handling missing value pada kolom `current_level`

# %% [markdown]
# **Insights:**
# - Terbukti bahwa pada kolom `current_level` terdapat missing value

# %%
# Mengecek jumlah duplikasi data
print(f'Jumlah duplikasi data user_progress_df: {user_progress_df.duplicated().sum()}')
# Out:
# Jumlah duplikasi data user_progress_df: 0

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights:**
# - `user_progress_df` tidak memiliki duplikasi data

# %%
# Mengecek deskriptif statistik
user_progress_df.describe(include='all')
# Out:
#              id user_id subchapter_id chapter_taken_id current_level  \
# count      1552    1552          1552             1552          1476
# unique     1500     788            21              851             3
# top     UP01500   S0364      SCT00008         CHT00952      advanced
# freq          2       7            90               10           505
#
#              status           created_at           updated_at
# count          1552                 1552                 1552
# unique            5                 1551                 1278
# top     in progress  2026-04-26 12:04:16  2026-04-27 23:18:52
# freq            484                    2                  274

# %% [markdown]
# **Steps to Take:**
# - Tidak ada

# %% [markdown]
# **Insights:**
# - Pada baris count kolom current_level, ia memiliki jumlah baris yang berbeda sendiri. Ini sesuai insights sebelumnya, yaitu kolom ini memang memiliki missing value
# - Pada baris top kolom current_level, terdapat nilai `advanced`. Hal ini menandakan bahwa kebanyakan siswa sudah diklasifikasikan skill matematikanya berada di level advanced
# - Pada baris top kolom status, terdapat nilai `in progress`. Hal ini menandakan bahwa kebanyakan siswa masih banyak yang maish progress kelasnya dan belum selesai

# %%
# Mengecek apakah ada perbedaan penulisan antara in-progress dengan in progress
user_progress_df[user_progress_df['status'] == 'in progress']
# Out:
#            id user_id subchapter_id chapter_taken_id current_level  \
# 7     UP00007   S0759      SCT00001         CHT00839      beginner
# 11    UP00011   S0423      SCT00017         CHT00440  intermediate
# 12    UP00012   S0072      SCT00001         CHT00701      advanced
# 15    UP00015   S0133      SCT00021         CHT00173      beginner
# 17    UP00017   S0067      SCT00012         CHT01104      beginner
# ...       ...     ...           ...              ...           ...
# 1541  UP01491   S0133      SCT00004         CHT00591      beginner
# 1547  UP01497   S0568      SCT00018         CHT00713  intermediate
# 1549  UP01499   S0584      SCT00002         CHT01105  intermediate
# 1550  UP01500   S0707      SCT00002         CHT00120      beginner
# 1551  UP01500   S0707      SCT00002         CHT00120      beginner
#
#            status           created_at           updated_at
# 7     in progress  2026-04-27 18:10:29  2026-04-27 23:18:52
# 11    in progress  2026-04-14 23:18:53  2026-04-15 23:35:53
# 12    in progress  2026-04-20 05:19:43  2026-04-21 05:36:43
# 15    in progress  2026-04-18 14:18:24  2026-04-19 14:35:24
# 17    in progress  2026-04-25 14:05:21  2026-04-26 14:22:21
# ...           ...                  ...                  ...
# 1541  in progress  2026-02-28 09:57:19  2026-03-01 10:14:19
# 1547  in progress  2026-03-13 14:28:55  2026-03-14 14:45:55
# 1549  in progress  2026-04-16 23:52:24  2026-04-18 00:09:24
# 1550  in progress  2026-04-20 10:21:57  2026-04-21 10:38:57
# 1551  in progress  2026-04-26 13:07:25  2026-04-27 13:24:25
#
# [484 rows x 8 columns]

# %% [markdown]
# **Steps to Take:**
# - Mengganti separator (pemisah) whitespace pada in progress menjadi tanda '-'

# %% [markdown]
# **Insights:**
# - Ternyata ada perbedaan penulisan pada status 'in progress' dengan 'in-progress'
# - Kita akan menggunakan patokan 'in-progress'

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing users_df problem

# %%
# Mengecek struktur data
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  1000 non-null   object
#  1   name        990 non-null    object
#  2   birth_date  966 non-null    object
#  3   role        978 non-null    object
#  4   email       976 non-null    object
#  5   password    982 non-null    object
#  6   created_at  1000 non-null   object
#  7   updated_at  1000 non-null   object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
# Mengubah tipe data kolom created_at dan updated_at
datetime_columns = ['created_at', 'updated_at']

for column in datetime_columns:
    users_df[column] = pd.to_datetime(users_df[column])

# %%
# Mengecek apakah tipe data sudah sesuai
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  1000 non-null   object
#  1   name        990 non-null    object
#  2   birth_date  966 non-null    object
#  3   role        978 non-null    object
#  4   email       976 non-null    object
#  5   password    982 non-null    object
#  6   created_at  1000 non-null   datetime64[ns]
#  7   updated_at  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(6)
# memory usage: 62.6+ KB

# %%
# Mendefinisikan kolom-kolom yang memiliki missing value
cols_with_missing = ['name', 'birth_date', 'role', 'email', 'password']

# %%
# Melihat baris yang NaN
users_df[users_df[['name', 'birth_date', 'role', 'email', 'password']].isnull().any(axis=1)]
# Out:
#     student_id              name  birth_date   role  \
# 8        S0009     Anisa Siregar  2013-12-23    NaN
# 14       S0015        Santi Sari  2014-01-02    NaN
# 20       S0021   Prabowo Tarigan         NaN  siswa
# 24       S0025               NaN  2013-08-25  siswa
# 32       S0033   Qomar Wulandari  2013-02-06  siswa
# ..         ...               ...         ...    ...
# 947      S0948       Rian Wijaya         NaN  siswa
# 966      S0967      Budi Hidayat  2012-01-30  siswa
# 982      S0983  Siti Simanjuntak         NaN  siswa
# 985      S0986       Agus Wijaya         NaN  siswa
# 988      S0989     Guntur Kusuma  2012-12-22    NaN
#
#                               email    password          created_at  \
# 8       anisa.siregar2884@gmail.com  CheMcXnhjl 2026-03-20 06:20:18
# 14         santi.sari3434@gmail.com  yODrPP5MNf 2026-04-15 19:54:44
# 20    prabowo.tarigan9551@gmail.com  VYVLkJNaHR 2026-02-28 04:44:19
# 24       gita.siregar5579@gmail.com  JrtN8cxBrG 2026-03-01 15:17:34
# 32                              NaN  U13L0WEBaP 2026-03-03 02:12:49
# ..                              ...         ...                 ...
# 947       rian.wijaya6017@gmail.com  UKYeuTssi0 2026-02-03 17:38:11
# 966                             NaN  K8nf4xGiIj 2026-03-06 23:59:30
# 982  siti.simanjuntak3340@gmail.com  31YQbGp4J9 2026-04-05 10:47:04
# 985       agus.wijaya8100@gmail.com  7O4S4XUeDy 2026-02-23 22:18:14
# 988     guntur.kusuma2343@gmail.com  GXcgoi46Z8 2026-03-29 16:28:39
#
#              updated_at
# 8   2026-04-07 11:10:59
# 14  2026-04-16 03:15:08
# 20  2026-03-10 08:31:46
# 24  2026-03-22 11:32:27
# 32  2026-03-03 02:12:49
# ..                  ...
# 947 2026-03-18 11:14:16
# 966 2026-04-22 22:51:47
# 982 2026-04-05 10:47:04
# 985 2026-03-03 23:25:43
# 988 2026-04-24 11:59:22
#
# [108 rows x 8 columns]

# %% [markdown]
# **Insights:**
# - Untuk kolom `name` yang kosong. Kita dapat mengisinya dari kolom `email` dan juga sebaliknya. Karena terdapat pola pengisian nama pada kolom `email`. Yaitu dengan `first_name.last_name@gmail.com`. Angkanya bisa kita abaikan untuk mengisian data 2 kolom tersebut.
# - Pengisian kolom `name` atau `email`, kita akan menggunakan teknik yang namanya `imputation`.
# - Unntuk kolom `role` terdapat yang NaN. Karena aplikasi kami dibuat hanya untuk siswa sejauh ini, maka nilai NaN ini bisa diisi dengan nilai `siswa`. Teknik yang digunakan adalah `imputation`
# - Pada kolom `password`, untuk pengisian nilai NaN nya bisa dengan string acak sesuai dengan password milik user lain
# - Untuk pengisian kolom `birth_date` yang memiliki nilai NaN, kami akan mengisinya pada tahun sekarang dikurangi umur anak kelas 7 SMP. Lalu tanggal dan bulannya akan kami acak. Teknik yang digunakan, `imputation`

# %% [markdown]
# ##### Pengisian nilai NaN pada kolom Name dan Email

# %%
# Filter baris yang memiliki nilai null pada kolom email
filter_name_and_email_null = users_df['name'].notnull() & users_df['email'].isna()

# %%
# Melihat baris yang diinginkan
users_df[filter_name_and_email_null]
# Out:
#     student_id              name  birth_date   role email    password  \
# 32       S0033   Qomar Wulandari  2013-02-06  siswa   NaN  U13L0WEBaP
# 48       S0049     Rina Setiawan  2014-06-17  siswa   NaN  5kRkfBDXpr
# 89       S0090     Aditya Rahayu  2013-05-09  siswa   NaN  YUEw5FmE1J
# 161      S0162   Farhan Setiawan  2014-05-03  siswa   NaN  9rhEDwUGz2
# 178      S0179     Prabowo Utami  2013-11-10  siswa   NaN  w21uuBRx2A
# 181      S0182    Taufik Purnama  2013-07-28  siswa   NaN  3WEnQvhIHF
# 231      S0232     Endah Siregar  2014-07-13  siswa   NaN  3bDBryIeI3
# - Kami akan mengisinya dengan mengambil first name dan last name pada kolom name. Pola pengisian nya yaitu `first_name.last_name@gmail.com`

# %%
# Mengisi nilai email yang NaN dengan pola yang sudah ditentukan
users_df.loc[filter_name_and_email_null, 'email'] = users_df.loc[filter_name_and_email_null, 'name'].str.lower().str.split().str.join('.') + '@gmail.com'
users_df[filter_name_and_email_null]
# Out:
#     student_id              name  birth_date   role  \
# 32       S0033   Qomar Wulandari  2013-02-06  siswa
# 48       S0049     Rina Setiawan  2014-06-17  siswa
# 89       S0090     Aditya Rahayu  2013-05-09  siswa
# 161      S0162   Farhan Setiawan  2014-05-03  siswa
# 178      S0179     Prabowo Utami  2013-11-10  siswa
# 181      S0182    Taufik Purnama  2013-07-28  siswa
# 231      S0232     Endah Siregar  2014-07-13  siswa
# 319      S0320  Santi Situmorang  2013-04-03  siswa
# 413      S0414       Oki Harahap  2013-06-11  siswa
# 488      S0489       Dedi Kusuma  2013-02-16  siswa
# 490      S0491   Lestari Purnama  2014-04-09  siswa
# 499      S0500     Gilang Wijaya  2014-02-04  siswa
# 512      S0513    Guntur Saputra  2012-09-06  siswa
# 615      S0616       Rina Kusuma  2014-02-07  siswa
# 624      S0625      Agus Siregar  2012-02-02  siswa
# 672      S0673      Maya Ginting  2011-07-18  siswa
# 677      S0678       Maya Wijaya  2013-03-11  siswa
# 716      S0717      Budi Gunawan  2011-03-11  siswa
# 812      S0813       Eko Gunawan  2012-05-25  siswa
# 818      S0819  Agus Simanjuntak  2012-07-11  siswa
# 864      S0865     Rina Nasution  2011-03-24  siswa
# 903      S0904       Eko Hidayat  2010-11-19  siswa
# 916      S0917      Rian Ginting  2013-03-15  siswa
# 966      S0967      Budi Hidayat  2012-01-30  siswa
#
#                           email    password          created_at  \
# 32    qomar.wulandari@gmail.com  U13L0WEBaP 2026-03-03 02:12:49
# 48      rina.setiawan@gmail.com  5kRkfBDXpr 2026-03-27 20:55:14
# 89      aditya.rahayu@gmail.com  YUEw5FmE1J 2026-03-28 12:28:05
# 161   farhan.setiawan@gmail.com  9rhEDwUGz2 2026-04-02 03:18:42
# 178     prabowo.utami@gmail.com  w21uuBRx2A 2026-03-20 06:46:05
# 181    taufik.purnama@gmail.com  3WEnQvhIHF 2026-03-13 07:38:41
# 231     endah.siregar@gmail.com  3bDBryIeI3 2026-04-08 06:19:31
# 319  santi.situmorang@gmail.com  sp7aX4WagX 2026-02-27 04:33:04
# 413       oki.harahap@gmail.com  IxCvF20gdj 2026-02-26 22:23:15
# 488       dedi.kusuma@gmail.com  QiT8JRLQTW 2026-04-01 11:23:45
# 490   lestari.purnama@gmail.com  nzDqkJBko7 2026-02-26 20:37:43
# 499     gilang.wijaya@gmail.com  DUQ615Zoyp 2026-03-07 18:04:22
# 512    guntur.saputra@gmail.com  8x41PeiDen 2026-02-25 13:49:38
# 615       rina.kusuma@gmail.com  OXPEOlsJnW 2026-02-07 21:16:17
# 624      agus.siregar@gmail.com  8aTQewN8U9 2026-02-19 01:06:21
# 672      maya.ginting@gmail.com  ItckI2rEIX 2026-03-01 22:38:24
# 430  iwAvVplipM 2026-03-11 12:09:27 2026-03-30 19:14:37
# 550  CK1gvdCy74 2026-03-11 06:41:53 2026-03-11 06:41:53
# 724  godd5WXWH7 2026-03-12 07:03:20 2026-03-19 22:20:55
# 741  T7FA2gQ9aB 2026-02-18 11:11:56 2026-02-18 11:11:56
# 750  K1FXN5T6ij 2026-04-24 22:42:12 2026-04-26 03:37:53
# 911  AswPUhKghB 2026-03-15 08:14:44 2026-03-15 08:14:44

# %% [markdown]
# **Insights:**
# - Di sini terdapat beberapa baris yang nilai nya NaN untuk kolom name.
# - Kami akan mengisinya dengan mengambil first name dan last name pada kolom email dan huruf pertama dari first_name dan last_name, akan dijadikan huruf besar lalu dipisahkan dengan spasi

# %%
# Mengambil first_name dan last_name dari email
first_name = users_df.loc[filter_name_null_and_email, 'email'].str.split(r'[.@]').str[0]
last_name = users_df.loc[filter_name_null_and_email, 'email'].str.split(r'[.@]').str[1].str.replace(r'\d+', '', regex=True)
first_name, last_name
# Out:
# (24       gita
#  54       rian
#  76      indra
#  133     putri
#  430    farhan
#  550      lani
#  724    guntur
#  741      maya
#  750      dewi
#  911     indah
#  Name: email, dtype: object,
#  24       siregar
#  54       pratama
#  76       permana
#  133      ginting
#  430    sembiring
#  550       wijaya
#  724     nasution
#  741     nasution
#  750      pratama
#  911      hidayat
#  Name: email, dtype: object)

# %%
# Mengisi name dari kolom email yang sudah dipisah first dan last name nya
users_df.loc[filter_name_null_and_email, 'name'] = first_name.str.title() + ' ' + last_name.str.title()
users_df[filter_name_null_and_email]
# Out:
#     student_id              name  birth_date   role  \
# 24       S0025      Gita Siregar  2013-08-25  siswa
# 54       S0055      Rian Pratama  2014-09-13  siswa
# 76       S0077     Indra Permana  2014-09-24  siswa
# 133      S0134     Putri Ginting  2013-05-25  siswa
# 430      S0431  Farhan Sembiring  2013-06-02  siswa
# 550      S0551       Lani Wijaya  2015-11-02  siswa
# 724      S0725   Guntur Nasution  2014-09-05  siswa
# 741      S0742     Maya Nasution  2014-02-03  siswa
# 750      S0751      Dewi Pratama  2012-11-13  siswa
# 911      S0912     Indah Hidayat  2012-10-12  siswa
#
#                               email    password          created_at  \
# 24       gita.siregar5579@gmail.com  JrtN8cxBrG 2026-03-01 15:17:34
# 54       rian.pratama7564@gmail.com  rX1mQ8FKzO 2026-03-09 01:05:11
# 76      indra.permana4338@gmail.com  cBLsZhGlxp 2026-04-18 02:20:30
# 133     putri.ginting4428@gmail.com  JhZxBwksPj 2026-02-03 06:24:41
# 430  farhan.sembiring2094@gmail.com  iwAvVplipM 2026-03-11 12:09:27
# 550       lani.wijaya5909@gmail.com  CK1gvdCy74 2026-03-11 06:41:53
# 724   guntur.nasution4193@gmail.com  godd5WXWH7 2026-03-12 07:03:20
# 741     maya.nasution7642@gmail.com  T7FA2gQ9aB 2026-02-18 11:11:56
# 750      dewi.pratama4952@gmail.com  K1FXN5T6ij 2026-04-24 22:42:12
# 911     indah.hidayat7483@gmail.com  AswPUhKghB 2026-03-15 08:14:44
#
#              updated_at
# 24  2026-03-22 11:32:27
# 54  2026-03-09 01:05:11
# 76  2026-04-20 21:16:07
# 133 2026-04-05 08:05:47
# 430 2026-03-30 19:14:37
# 550 2026-03-11 06:41:53
# 724 2026-03-19 22:20:55
# 741 2026-02-18 11:11:56
# 750 2026-04-26 03:37:53
# 911 2026-03-15 08:14:44

# %% [markdown]
# **Insights:**
# - Kolom name sudah diisikan nilainya dan sudah sesuai

# %% [markdown]
# ##### Pengisian nilai NaN pada kolom role

# %%
# Filter baris pada kolom role yang NaN
filter_role_null = users_df['role'].isna()

# %%
# Melihat baris yang memiliki nilai NaN pada kolom role
users_df[filter_role_null]
# Out:
#     student_id              name  birth_date role  \
# 8        S0009     Anisa Siregar  2013-12-23  NaN
# 14       S0015        Santi Sari  2014-01-02  NaN
# 126      S0127      Putri Wijaya  2013-12-23  NaN
# 192      S0193  Bambang Nasution  2014-07-26  NaN
# 197      S0198    Hany Wulandari  2014-04-12  NaN
# 293      S0294     Fajar Hidayat  2014-10-17  NaN
# 386      S0387    Gilang Lestari  2013-05-13  NaN
# 390      S0391   Gilang Setiawan  2014-08-24  NaN
# 394      S0395      Ahmad Rahayu  2013-04-25  NaN
# 474      S0475      Doni Hidayat  2013-02-27  NaN
# 561      S0562     Joko Nasution  2012-01-21  NaN
# 622      S0623      Siti Pratama  2013-02-08  NaN
# 689      S0690      Sari Saputra  2011-02-08  NaN
# 695      S0696       Agus Wijaya  2011-06-06  NaN
# 732      S0733      Andi Hidayat  2015-01-22  NaN
# 753      S0754      Rian Lestari  2013-10-02  NaN
# 777      S0778      Siti Saputra  2012-02-26  NaN
# 827      S0828      Agus Siregar  2014-06-08  NaN
# 885      S0886      Siti Hidayat  2015-11-20  NaN
# 887      S0888     Agus Nasution  2013-03-04  NaN
# 895      S0896       Rian Kusuma  2015-02-14  NaN
# 988      S0989     Guntur Kusuma  2012-12-22  NaN
#
#                               email    password          created_at  \
# 8       anisa.siregar2884@gmail.com  CheMcXnhjl 2026-03-20 06:20:18
# 14         santi.sari3434@gmail.com  yODrPP5MNf 2026-04-15 19:54:44
# 126      putri.wijaya4750@gmail.com  S37tgi6v8z 2026-03-05 08:15:26
# 192  bambang.nasution3249@gmail.com  gqJZUfh4or 2026-04-20 20:36:41
# 197     hany.wulandari278@gmail.com  Gdqhf4kxrI 2026-02-14 00:19:00
# 293     fajar.hidayat9190@gmail.com  RZD9JOa9CT 2026-04-25 20:21:05
# 386     gilang.lestari490@gmail.com  GTFndUytii 2026-04-15 10:08:33
# 390   gilang.setiawan5421@gmail.com  b1wQE5U17W 2026-04-27 13:40:58
# 394      ahmad.rahayu2518@gmail.com  0sdOxKDJUn 2026-03-28 21:25:53
# 474      doni.hidayat3828@gmail.com  Fw8LVoskuD 2026-03-10 16:20:48
# 561     joko.nasution7991@gmail.com  8oj201sEou 2026-02-04 23:39:47
# 622      siti.pratama1374@gmail.com  YsB3TRkXiO 2026-02-23 22:06:22
# 689      sari.saputra5496@gmail.com  uzOaWgJvPs 2026-03-25 22:48:05
# 695       agus.wijaya3903@gmail.com  HUt8s6rSJ5 2026-04-02 18:58:48
# 164      S0165        Cahyo Lubis  2014-11-06  siswa
# 169      S0170     Taufik Ginting  2014-11-01  siswa
# 204      S0205       Rina Tarigan  2013-11-22  siswa
# 271      S0272      Cahyo Saputra  2013-12-21  siswa
# 318      S0319  Maya Hidayatullah  2013-06-26  siswa
# 376      S0377       Rina Permana  2014-04-21  siswa
# 592      S0593      Indah Pratama  2012-07-05  siswa
# 619      S0620     Guntur Hidayat  2010-03-23  siswa
# 649      S0650         Eko Kusuma  2012-08-19  siswa
# 652      S0653       Lani Hidayat  2012-10-27  siswa
# 694      S0695        Budi Wijaya  2014-05-16  siswa
# 723      S0724       Rina Gunawan  2014-11-13  siswa
# 751      S0752       Rina Gunawan  2013-09-16  siswa
# 784      S0785       Agus Hidayat  2014-10-11  siswa
# 788      S0789       Dewi Siregar  2010-11-12  siswa
# 843      S0844      Rina Nasution  2014-04-07  siswa
#
#                                email password          created_at  \
# 127        lestari.pane811@gmail.com      NaN 2026-04-25 15:48:56
# 153    bambang.nugraha9772@gmail.com      NaN 2026-04-16 05:44:28
# 164        cahyo.lubis3590@gmail.com      NaN 2026-02-26 17:27:54
# 169     taufik.ginting9620@gmail.com      NaN 2026-04-05 17:42:44
# 204       rina.tarigan2868@gmail.com      NaN 2026-02-14 19:41:28
# 271      cahyo.saputra3432@gmail.com      NaN 2026-02-16 08:52:01
# 318  maya.hidayatullah5067@gmail.com      NaN 2026-03-11 13:57:06
# 376       rina.permana4623@gmail.com      NaN 2026-04-02 11:32:55
# 592      indah.pratama1825@gmail.com      NaN 2026-02-07 06:27:03
# 619     guntur.hidayat3989@gmail.com      NaN 2026-03-22 21:31:35
# 649         eko.kusuma9299@gmail.com      NaN 2026-04-25 12:26:43
# 652       lani.hidayat2920@gmail.com      NaN 2026-03-03 18:39:22
# 694        budi.wijaya2904@gmail.com      NaN 2026-02-13 20:10:43
# 723       rina.gunawan3066@gmail.com      NaN 2026-04-08 06:31:11
# 751       rina.gunawan8370@gmail.com      NaN 2026-03-24 11:54:35
# 784       agus.hidayat2778@gmail.com      NaN 2026-03-18 14:00:16
# 788       dewi.siregar8838@gmail.com      NaN 2026-02-06 13:41:48
# 843      rina.nasution7668@gmail.com      NaN 2026-04-20 08:17:16
#
#              updated_at
# 127 2026-04-25 15:48:56
# 153 2026-04-22 01:34:21
# 164 2026-03-11 17:27:40
# 169 2026-04-05 17:42:44
# 204 2026-03-02 12:16:27
# 271 2026-02-16 08:52:01
# 318 2026-03-11 13:57:06
# 376 2026-04-08 14:48:21
# 592 2026-03-06 04:03:09
# 619 2026-03-22 21:31:35
# 649 2026-04-25 12:26:43
# 652 2026-03-12 09:36:29
# 694 2026-03-16 19:51:25
# 723 2026-04-08 06:31:11
# 751 2026-03-24 11:54:35
# 784 2026-03-23 11:09:50
# 788 2026-02-06 13:41:48
# 843 2026-04-22 19:05:00

# %%
# Membuat random text yang berisi angka, karakter lowercase dan uppercase secara random
characters = string.ascii_letters + string.digits
users_df.loc[filter_password_null, 'password'] = [''.join(random.choices(characters, k=8)) for _ in range(len(users_df[filter_password_null]))]

# 694 2026-03-16 19:51:25
# 723 2026-04-08 06:31:11
# 751 2026-03-24 11:54:35
# 784 2026-03-23 11:09:50
# 788 2026-02-06 13:41:48
# 843 2026-04-22 19:05:00

# %% [markdown]
# ##### Pengisian nilai NaN pada kolom birth_date

# %%
# Filter baris yang memiliki NaN value
filter_birth_date_null = users_df['birth_date'].isna()

# %%
# Melihat baris yang memiliki nilai NaN
users_df[filter_birth_date_null]
# Out:
#     student_id               name birth_date   role  \
# 20       S0021    Prabowo Tarigan        NaN  siswa
# 91       S0092      Qori Ramadhan        NaN  siswa
# 102      S0103      Fajar Harahap        NaN  siswa
# 114      S0115       Putri Sinaga        NaN  siswa
# 122      S0123       Doni Ginting        NaN  siswa
# 144      S0145       Kevin Kusuma        NaN  siswa
# 211      S0212     Farhan Siregar        NaN  siswa
# 212      S0213   Lestari Ramadhan        NaN  siswa
# 253      S0254      Indah Nugraha        NaN  siswa
# 296      S0297      Cahyo Saputra        NaN  siswa
# 311      S0312     Citra Fitriani        NaN  siswa
# 316      S0317    Chandra Gunawan        NaN  siswa
# 334      S0335      Fajar Pratama        NaN  siswa
# 343      S0344        Fitri Utami        NaN  siswa
# 360      S0361       Nina Ginting        NaN  siswa
# 365      S0366         Santi Sari        NaN  siswa
# 379      S0380  Bambang Sembiring        NaN  siswa
# 415      S0416          Maya Sari        NaN  siswa
# 435      S0436      Santi Lestari        NaN  siswa
# 462      S0463    Suryo Sembiring        NaN  siswa
# 521      S0522      Lani Nasution        NaN  siswa
# 569      S0570       Sari Siregar        NaN  siswa
# 602      S0603       Dewi Gunawan        NaN  siswa
# 609      S0610       Andi Pratama        NaN  siswa
# 631      S0632      Indah Gunawan        NaN  siswa
# 714      S0715       Sari Ginting        NaN  siswa
# 811      S0812       Budi Siregar        NaN  siswa
# 829      S0830       Joko Lestari        NaN  siswa
# 888      S0889     Guntur Pratama        NaN  siswa
# 898      S0899       Joko Hidayat        NaN  siswa
# 924      S0925       Agus Hidayat        NaN  siswa
# 947      S0948        Rian Wijaya        NaN  siswa
# 982      S0983   Siti Simanjuntak        NaN  siswa
# 985      S0986        Agus Wijaya        NaN  siswa
#
#                               email    password          created_at  \
# 20    prabowo.tarigan9551@gmail.com  VYVLkJNaHR 2026-02-28 04:44:19
# 91      qori.ramadhan1490@gmail.com  b8OutAeu1l 2026-03-09 13:40:26
# 102     fajar.harahap8173@gmail.com  E7p5mzR98u 2026-02-15 07:03:07
# 114      putri.sinaga1773@gmail.com  VJFvblY53k 2026-03-18 20:30:08
# 122       doni.ginting962@gmail.com  hJqP2x95in 2026-04-20 14:06:18
# 144      kevin.kusuma1542@gmail.com  tr69rRT7BV 2026-04-26 20:22:11
# 211    farhan.siregar6670@gmail.com  BGHoa28Hw6 2026-03-24 01:41:32
# 212  lestari.ramadhan1035@gmail.com  9VFZzbBT3J 2026-03-08 10:19:06
# 253      indah.nugraha406@gmail.com  CCCda94NEE 2026-02-06 12:14:18
# 296     cahyo.saputra2574@gmail.com  ftXK1VdmJF 2026-03-17 18:46:25
# 924 2026-02-21 08:50:24
# 947 2026-03-18 11:14:16
# 982 2026-04-05 10:47:04
# 985 2026-03-03 23:25:43

# %%
# Menentukan random dates yang memfokuskan tahun di 2013
random_dates = pd.to_datetime('2013-01-01') + pd.to_timedelta(np.random.randint(0, 365, size=filter_birth_date_null.sum()), unit='D')

# %%
users_df.loc[filter_birth_date_null, 'birth_date'] = random_dates.strftime('%Y-%m-%d')

# %%
users_df[filter_birth_date_null]
# Out:
#     student_id               name  birth_date   role  \
# 20       S0021    Prabowo Tarigan  2013-12-24  siswa
# 91       S0092      Qori Ramadhan  2013-12-25  siswa
# 102      S0103      Fajar Harahap  2013-04-29  siswa
# 114      S0115       Putri Sinaga  2013-03-25  siswa
# 122      S0123       Doni Ginting  2013-03-04  siswa
# 144      S0145       Kevin Kusuma  2013-07-02  siswa
# 211      S0212     Farhan Siregar  2013-05-17  siswa
# 212      S0213   Lestari Ramadhan  2013-05-12  siswa
# 253      S0254      Indah Nugraha  2013-07-26  siswa
# 296      S0297      Cahyo Saputra  2013-09-06  siswa
# 311      S0312     Citra Fitriani  2013-10-21  siswa
# 316      S0317    Chandra Gunawan  2013-02-01  siswa
# 334      S0335      Fajar Pratama  2013-07-12  siswa
# 343      S0344        Fitri Utami  2013-05-09  siswa
# 360      S0361       Nina Ginting  2013-05-23  siswa
# 365      S0366         Santi Sari  2013-06-06  siswa
# 379      S0380  Bambang Sembiring  2013-04-20  siswa
# 415      S0416          Maya Sari  2013-05-17  siswa
# 435      S0436      Santi Lestari  2013-10-31  siswa
# 462      S0463    Suryo Sembiring  2013-10-22  siswa
# 521      S0522      Lani Nasution  2013-03-26  siswa
# 569      S0570       Sari Siregar  2013-06-07  siswa
# 602      S0603       Dewi Gunawan  2013-08-25  siswa
# 609      S0610       Andi Pratama  2013-02-09  siswa
# 631      S0632      Indah Gunawan  2013-06-07  siswa
# 714      S0715       Sari Ginting  2013-07-14  siswa
# 811      S0812       Budi Siregar  2013-08-25  siswa
# 829      S0830       Joko Lestari  2013-12-28  siswa
# 888      S0889     Guntur Pratama  2013-10-03  siswa
# 898      S0899       Joko Hidayat  2013-03-02  siswa
# 924      S0925       Agus Hidayat  2013-04-13  siswa
# 947      S0948        Rian Wijaya  2013-06-16  siswa
# 982      S0983   Siti Simanjuntak  2013-07-19  siswa
# 985      S0986        Agus Wijaya  2013-12-09  siswa
#
#                               email    password          created_at  \
# 20    prabowo.tarigan9551@gmail.com  VYVLkJNaHR 2026-02-28 04:44:19
# 91      qori.ramadhan1490@gmail.com  b8OutAeu1l 2026-03-09 13:40:26
# 102     fajar.harahap8173@gmail.com  E7p5mzR98u 2026-02-15 07:03:07
# 114      putri.sinaga1773@gmail.com  VJFvblY53k 2026-03-18 20:30:08
# 122       doni.ginting962@gmail.com  hJqP2x95in 2026-04-20 14:06:18
# 144      kevin.kusuma1542@gmail.com  tr69rRT7BV 2026-04-26 20:22:11
# 211    farhan.siregar6670@gmail.com  BGHoa28Hw6 2026-03-24 01:41:32
# 212  lestari.ramadhan1035@gmail.com  9VFZzbBT3J 2026-03-08 10:19:06
# 631 2026-03-22 06:22:24
# 714 2026-04-13 16:52:50
# 811 2026-03-13 23:37:42
# 829 2026-02-10 13:37:00
# 888 2026-04-12 03:18:45
# 898 2026-04-06 07:38:30
# 924 2026-02-21 08:50:24
# 947 2026-03-18 11:14:16
# 982 2026-04-05 10:47:04
# 985 2026-03-03 23:25:43

# %% [markdown]
# **Insights:**
# - Kolom birth_date sudah tidak ada yang NaN

# %%
# Mengecek kembali apakah masih terdapat missing value
users_df.isna().sum()
# Out:
# student_id    0
# name          0
# birth_date    0
# role          0
# email         0
# password      0
# created_at    0
# updated_at    0
# dtype: int64

# %% [markdown]
# **Insights:**
# - Data users_df kali ini sudah bersih. Tidak ada lagi missing value

# %%
# Mengecek apakah ada format yang tidak sesuai dengan format YYYY-MM-DD pada kolom birth_date
pattern_date = r'^\d{4}-\d{2}-\d{2}$'
users_df[~users_df['birth_date'].str.match(pattern_date)]
# Out:
#     student_id            name birth_date   role  \
# 566      S0567    Sari Ginting   07/07/11  siswa
# 710      S0711    Maya Hidayat   15/05/10  siswa
# 722      S0723    Sari Siregar   10/02/15  siswa
# 749      S0750    Agus Lestari   13/05/11  siswa
# 800      S0801     Budi Wijaya   23/02/14  siswa
# 854      S0855     Dewi Wijaya   10/11/12  siswa
# 897      S0898  Guntur Pratama   31/12/10  siswa
# 928      S0929    Dewi Gunawan   07/09/12  siswa
# 979      S0980   Taufik Kusuma   12/01/10  siswa
#
#                             email    password          created_at  \
# 566    sari.ginting1540@gmail.com  qGThR9BolG 2026-02-15 13:05:47
# 710    maya.hidayat2682@gmail.com  ig83mq3QWi 2026-04-01 15:39:02
# 722    sari.siregar2870@gmail.com  L25laL8tpN 2026-02-15 04:09:31
# 749    agus.lestari1142@gmail.com  pgUaq9QDos 2026-03-13 04:19:24
# 800     budi.wijaya8410@gmail.com  G0DJX7ZjRo 2026-03-25 10:01:00
# 854     dewi.wijaya8265@gmail.com  ZLAx2sd3rK 2026-03-05 12:21:52
# 897  guntur.pratama8019@gmail.com  maZaiG7eDJ 2026-03-28 18:10:31
# 928    dewi.gunawan3683@gmail.com  L5rAhudH35 2026-03-01 20:42:18
# 979   taufik.kusuma3685@gmail.com  8NP4Ver5gj 2026-03-17 22:28:26
#
#              updated_at
# 566 2026-03-11 19:40:47
# 710 2026-04-18 06:30:50
# 722 2026-04-04 11:34:33
# 749 2026-03-13 04:19:24
# 800 2026-04-09 01:58:08
# 854 2026-04-27 22:50:06
# 897 2026-04-16 15:17:10
# 928 2026-04-16 15:31:50
# 979 2026-03-17 22:28:26

# %% [markdown]
# **Insights:**
# - Terdapat pattern yang tidak sesuai dengan pattern YYYY-MM-DD. Hal ini perlu diperbaiki

# %% [markdown]
# ##### Perbaikan pattern birth_date pada users_df

# %%
# Menampilkan baris yang patternnya tidak konsisten pada kolom birth_date
pattern_date = r'^\d{4}-\d{2}-\d{2}$'
users_df[~users_df['birth_date'].str.match(pattern_date)]
# Out:
#     student_id            name birth_date   role  \
# 566      S0567    Sari Ginting   07/07/11  siswa
# 710      S0711    Maya Hidayat   15/05/10  siswa
# 722      S0723    Sari Siregar   10/02/15  siswa
# 749      S0750    Agus Lestari   13/05/11  siswa
# 800      S0801     Budi Wijaya   23/02/14  siswa
# 854      S0855     Dewi Wijaya   10/11/12  siswa
# 897      S0898  Guntur Pratama   31/12/10  siswa
# 928      S0929    Dewi Gunawan   07/09/12  siswa
# 979      S0980   Taufik Kusuma   12/01/10  siswa
#
#                             email    password          created_at  \
# 566    sari.ginting1540@gmail.com  qGThR9BolG 2026-02-15 13:05:47
# 710    maya.hidayat2682@gmail.com  ig83mq3QWi 2026-04-01 15:39:02
# 722    sari.siregar2870@gmail.com  L25laL8tpN 2026-02-15 04:09:31
# 749    agus.lestari1142@gmail.com  pgUaq9QDos 2026-03-13 04:19:24
# 800     budi.wijaya8410@gmail.com  G0DJX7ZjRo 2026-03-25 10:01:00
# 854     dewi.wijaya8265@gmail.com  ZLAx2sd3rK 2026-03-05 12:21:52
# 897  guntur.pratama8019@gmail.com  maZaiG7eDJ 2026-03-28 18:10:31
# 928    dewi.gunawan3683@gmail.com  L5rAhudH35 2026-03-01 20:42:18
# 979   taufik.kusuma3685@gmail.com  8NP4Ver5gj 2026-03-17 22:28:26
#
#              updated_at
# 566 2026-03-11 19:40:47
# 710 2026-04-18 06:30:50
# 722 2026-04-04 11:34:33
# 749 2026-03-13 04:19:24
# 800 2026-04-09 01:58:08
# 854 2026-04-27 22:50:06
# 897 2026-04-16 15:17:10
# 928 2026-04-16 15:31:50
# 979 2026-03-17 22:28:26

# %%
# Mengubah pattern DD/MM/YY menjadi YYYY-MM-DD
wrong_pattern = users_df['birth_date'].str.contains('/', na=False)

users_df.loc[wrong_pattern, 'birth_date'] = pd.to_datetime(
    users_df.loc[wrong_pattern, 'birth_date'],
    format='%d/%m/%y'
).dt.strftime('%Y-%m-%d')

# %%
# Mengecek hasil
users_df[~users_df['birth_date'].str.match(pattern_date)]
# Out:
# Empty DataFrame
# Columns: [student_id, name, birth_date, role, email, password, created_at, updated_at]
# Index: []

# %% [markdown]
# **Insights:**
# - Tidak muncul baris apapun. Artinya, semua pattern pada kolom birth_date sudah sama semua

# %%
# Hasil akhir struktur data 
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  1000 non-null   object
#  1   name        1000 non-null   object
#  2   birth_date  1000 non-null   object
#  3   role        1000 non-null   object
#  4   email       1000 non-null   object
#  5   password    1000 non-null   object
#  6   created_at  1000 non-null   datetime64[ns]
#  7   updated_at  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(6)
# memory usage: 62.6+ KB

# %% [markdown]
# #### Fixing chapters_df problem

# %%
# Mengecek struktur data
chapters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                6 non-null      object
#  1   name              6 non-null      object
#  2   total_subchapter  6 non-null      int64
#  3   created_at        6 non-null      object
#  4   updated_at        6 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 372.0+ bytes

# %% [markdown]
# **Insights:**
# - Kolom created_at dan updated_at masih kurang tepat tipe datanya. Harusnya datetime

# %%
# Mengubah tipe data created_at dan updated_at
for column in datetime_columns: # Ambil variabel datetime_columns, karena kolom yang ingin dikonversi data typenya, sama
    chapters_df[column] = pd.to_datetime(chapters_df[column])

# %%
# Mengecek kembali struktur data
chapters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                6 non-null      object
#  1   name              6 non-null      object
#  2   total_subchapter  6 non-null      int64
#  3   created_at        6 non-null      datetime64[ns]
#  4   updated_at        6 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 372.0+ bytes

# %% [markdown]
# **Insights:**
# - Sekarang, kolom created_at dan updated_at sudah tepat tipe datanya

# %%
# Melihat baris chpaters_df
chapters_df
# Out:
#         id               name  total_subchapter created_at updated_at
# 0  CT00001     Bilangan Bulat                 3 2026-01-01 2026-01-01
# 1  CT00002  Bilangan Rasional                 3 2026-01-01 2026-01-01
# 2  CT00003              Rasio                 3 2026-01-01 2026-01-01
# 3  CT00004     Bentuk Aljabar                 3 2026-01-01 2026-01-01
# 4  CT00005       Kesebangunan                 3 2026-01-01 2026-01-01
# 5  CT00006   Data dan Diagram                 6 2026-01-01 2026-01-01

# %% [markdown]
# **Insights:**
# - Tidak ada keanehan dalam data ini. Artinya data chapters_df sudah bersih

# %% [markdown]
# #### Fixing subchapters_df problem

# %%
# Mengecek struktur data
subchapters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          21 non-null     object
#  1   chapter_id  21 non-null     object
#  2   name        21 non-null     object
#  3   created_at  21 non-null     object
#  4   updated_at  21 non-null     object
# dtypes: object(5)
# memory usage: 972.0+ bytes

# %% [markdown]
# **Insights:**
# - Tipe data kolom created_at dan updated_at, harusnya datetime.
# - Semua baris jumlahnya sama pada setiap kolom, artinya tidak ada missing value

# %%
# Mengubah tipe data 2 kolom tadi
for column in datetime_columns:
    subchapters_df[column] = pd.to_datetime(subchapters_df[column])

# %%
# Mengecek kembali struktur datanya
subchapters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          21 non-null     object
#  1   chapter_id  21 non-null     object
#  2   name        21 non-null     object
#  3   created_at  21 non-null     datetime64[ns]
#  4   updated_at  21 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), object(3)
# memory usage: 972.0+ bytes

# %% [markdown]
# **Insights:**
# - Sekarang tipe datanya sudah sesuai untuk setiap kolom
# - Data ini sudah bersih dan siap digunakan pada proses EDA

# %% [markdown]
# #### Fixing chapters_taken_df problem

# %%
# Mengecek struktur data
chapters_taken_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1220 non-null   object
#  1   user_id       1220 non-null   object
#  2   chapter_id    1220 non-null   object
#  3   created_at_x  1220 non-null   object
#  4   updated_at    1220 non-null   object
#  5   created_at    1220 non-null   object
# dtypes: object(6)
# memory usage: 57.3+ KB

# %% [markdown]
# **Insights:**
# - Kolom created_at dan updated_at, memiliki tipe data yang seharusnya datetime
# - Jumlah baris setiap kolom, sama. Artinya data ini tidak ada missing value

# %%
# Mengubah tipe data 2 kolom tadi
for column in datetime_columns:
    chapters_taken_df[column] = pd.to_datetime(chapters_taken_df[column])

# %%
# Mengecek kembali struktur datanya
chapters_taken_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1220 non-null   object
#  1   user_id       1220 non-null   object
#  2   chapter_id    1220 non-null   object
#  3   created_at_x  1220 non-null   object
#  4   updated_at    1220 non-null   datetime64[ns]
#  5   created_at    1220 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(4)
# memory usage: 57.3+ KB

# %% [markdown]
# **Insights:**
# - Kolom created_at dan updated_at, sudah memiliki tipe data yang tepat

# %%
# Mencari tau informasi data dari fitur created_at_x
chapters_taken_df.head()
# Out:
#          id user_id chapter_id         created_at_x          updated_at  \
# 0  CHT00001   S0331    CT00002  2025-01-16 00:14:42 2026-04-27 23:18:52
# 1  CHT00002   S0242    CT00002  2024-07-20 18:18:07 2026-04-06 12:52:29
# 2  CHT00003   S0181    CT00006  2025-01-14 04:34:27 2026-04-12 00:35:07
# 3  CHT00004   S0145    CT00003  2025-02-13 19:24:19 2026-04-27 23:18:52
# 4  CHT00005   S0116    CT00006  2024-09-17 06:35:49 2026-04-20 18:32:43
#
#            created_at
# 0 2026-04-25 03:10:15
# 1 2026-04-01 19:01:29
# 2 2026-04-07 06:44:07
# 3 2026-04-26 22:45:20
# 4 2026-04-16 00:41:43

# %% [markdown]
# **Insights:**
# - Kolom created_at_x ini tidak tahu berasal dari mana
# - Yang jelas, kolom created_at_x tidak bisa digunakan. Kenapa? Karena chapter_id CT00002 pada data chapters_df, baru dibuat tahun 2026. Sedangkan di created_at_x, ada pada tahun 2025 bahkan 2024
# - Jadi kami akan drop kolom created_at_x

# %%
# Menghapus kolom created_at_x
chapters_taken_df.drop(columns='created_at_x', inplace=True)

# %%
# Melihat kembali struktur data
chapters_taken_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1220 non-null   object
#  1   user_id     1220 non-null   object
#  2   chapter_id  1220 non-null   object
#  3   updated_at  1220 non-null   datetime64[ns]
#  4   created_at  1220 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(3)
# memory usage: 47.8+ KB

# %% [markdown]
# **Insights:**
# - Sekarang, kolom created_at_x sudah tidak ada dan datanya sudah bersih

# %% [markdown]
# #### Fixing assessment_df problem

# %%
# Mengecek struktur data
assessments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                206 non-null    object
#  1   chapter_taken_id  206 non-null    object
#  2   subchapter_id     206 non-null    object
#  3   title             206 non-null    object
#  4   type              206 non-null    object
#  5   correct_answer    195 non-null    float64
#  6   created_at        206 non-null    object
#  7   updated_at        206 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 13.0+ KB

# %% [markdown]
# **Insights:**
# - Kita akan ubah tipe data created_at dan updated_at menjadi datetime
# - Lalu akan menghandle missing value correct answer

# %%
# Mengubah tipe dadta created_at dan updated_at menggunakan variabel datetime_columns
for column in datetime_columns:
    assessments_df[column] = pd.to_datetime(assessments_df[column])

# %%
# Mengecek kembali struktur datanya
assessments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                206 non-null    object
#  1   chapter_taken_id  206 non-null    object
#  2   subchapter_id     206 non-null    object
#  3   title             206 non-null    object
#  4   type              206 non-null    object
#  5   correct_answer    195 non-null    float64
#  6   created_at        206 non-null    datetime64[ns]
#  7   updated_at        206 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(5)
# memory usage: 13.0+ KB

# %% [markdown]
# **Insights:**
# - Kolom created_at dan updated_at sudah sesuai sekarang

# %%
# Mengecek baris yang memiliki null value
filter_correct_answer_null = assessments_df['correct_answer'].isna()
assessments_df[filter_correct_answer_null]
# Out:
#           id chapter_taken_id subchapter_id           title       type  \
# 24   AS00024         CHT00160      SCT00015   Assessment 24  placement
# 45   AS00044         CHT00958      SCT00004   Assessment 44       exam
# 69   AS00068         CHT00509      SCT00005   Assessment 68  placement
# 73   AS00072         CHT00534      SCT00002   Assessment 72       exam
# 89   AS00088         CHT00503      SCT00004   Assessment 88       exam
# 100  AS00099         CHT00026      SCT00016   Assessment 99       quiz
# 127  AS00125         CHT00073      SCT00017  Assessment 125       quiz
# 128  AS00126         CHT00519      SCT00001  Assessment 126       exam
# 129  AS00126         CHT00519      SCT00001  Assessment 126       exam
# 133  AS00130         CHT00652      SCT00001  Assessment 130  placement
# 180  AS00175         CHT00004      SCT00005  Assessment 175       quiz
#
#      correct_answer          created_at          updated_at
# 24              NaN 2026-04-27 22:10:04 2026-04-27 22:57:04
# 45              NaN 2026-03-28 08:33:21 2026-03-28 09:20:21
# 69              NaN 2026-04-26 22:32:27 2026-04-26 23:19:27
# 73              NaN 2026-04-26 19:50:36 2026-04-26 20:37:36
# 89              NaN 2026-03-27 00:08:17 2026-03-27 00:55:17
# 100             NaN 2026-04-08 13:00:44 2026-04-08 13:47:44
# 127             NaN 2026-03-29 05:14:02 2026-03-29 06:01:02
# 128             NaN 2026-03-25 13:15:19 2026-03-25 14:02:19
# 129             NaN 2026-04-22 07:31:02 2026-04-22 08:18:02
# 133             NaN 2026-04-27 16:26:06 2026-04-27 17:13:06
# 180             NaN 2026-04-27 11:49:48 2026-04-27 12:36:48

# %% [markdown]
# **Insights:**
# - Karena correct_answer ini hanya sedikit yang missing value, kita akan melakukan imputation
# - Imputation dilakukan dengan mengisi nilai mode dari correct_answer

# %%
# Mengecek nilai mode (modus) dari correct_answer
mode_correct_answer = assessments_df['correct_answer'].mode().values[0]
print(f'Nilai mode pada kolom correct_answer: {mode_correct_answer}')
# Out:
# Nilai mode pada kolom correct_answer: 23.0

# %%
# Mengisi nilai NaN dengan nilai mode
assessments_df['correct_answer'].fillna(mode_correct_answer, inplace=True)
# Out:
# C:\Users\Hype AMD\AppData\Local\Temp\ipykernel_29924\4229186351.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   assessments_df['correct_answer'].fillna(mode_correct_answer, inplace=True)

# %%
# Mengecek kembali apakah nilainya sudah terisi
assessments_df[filter_correct_answer_null]
# Out:
#           id chapter_taken_id subchapter_id           title       type  \
# 24   AS00024         CHT00160      SCT00015   Assessment 24  placement
# 45   AS00044         CHT00958      SCT00004   Assessment 44       exam
# 69   AS00068         CHT00509      SCT00005   Assessment 68  placement
# 73   AS00072         CHT00534      SCT00002   Assessment 72       exam
# 89   AS00088         CHT00503      SCT00004   Assessment 88       exam
# 100  AS00099         CHT00026      SCT00016   Assessment 99       quiz
# 127  AS00125         CHT00073      SCT00017  Assessment 125       quiz
# 128  AS00126         CHT00519      SCT00001  Assessment 126       exam
# 129  AS00126         CHT00519      SCT00001  Assessment 126       exam
# 133  AS00130         CHT00652      SCT00001  Assessment 130  placement
# 180  AS00175         CHT00004      SCT00005  Assessment 175       quiz
#
#      correct_answer          created_at          updated_at
# 24             23.0 2026-04-27 22:10:04 2026-04-27 22:57:04
# 45             23.0 2026-03-28 08:33:21 2026-03-28 09:20:21
# 69             23.0 2026-04-26 22:32:27 2026-04-26 23:19:27
# 73             23.0 2026-04-26 19:50:36 2026-04-26 20:37:36
# 89             23.0 2026-03-27 00:08:17 2026-03-27 00:55:17
# 100            23.0 2026-04-08 13:00:44 2026-04-08 13:47:44
# 127            23.0 2026-03-29 05:14:02 2026-03-29 06:01:02
# 128            23.0 2026-03-25 13:15:19 2026-03-25 14:02:19
# 129            23.0 2026-04-22 07:31:02 2026-04-22 08:18:02
# 133            23.0 2026-04-27 16:26:06 2026-04-27 17:13:06
# 180            23.0 2026-04-27 11:49:48 2026-04-27 12:36:48

# %% [markdown]
# **Insights:**
# - Nilai NaN sudah terisi dengan nilai mode nya. Sekarang datanya sudah bersih

# %%
# Memastikan apakah datanya sudah bersih
assessments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                206 non-null    object
#  1   chapter_taken_id  206 non-null    object
#  2   subchapter_id     206 non-null    object
#  3   title             206 non-null    object
#  4   type              206 non-null    object
#  5   correct_answer    206 non-null    float64
#  6   created_at        206 non-null    datetime64[ns]
#  7   updated_at        206 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(5)
# memory usage: 13.0+ KB

# %% [markdown]
# **Insights:**
# - Sekarang datanya sudah bersih

# %% [markdown]
# #### Fixing user_attempts_df problem

# %%
# Mengecek struktur data
user_attempts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2053 entries, 0 to 2052
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2053 non-null   object
#  1   user_id        2053 non-null   object
#  2   assessment_id  2053 non-null   object
#  3   score          2053 non-null   float64
#  4   completed_at   2053 non-null   object
#  5   created_at     2053 non-null   object
#  6   updated_at     2053 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 112.4+ KB

# %% [markdown]
# **Insights:**
# - Tidak ada indikasi missing value di setiap kolomnya
# - Tipe data kolom created_at dan updated_at akan diubah menjadi datetime

# %%
# Mengubah tipe data kolom created_at dan updated_at menggunakan variabel datetime_columns
for column in datetime_columns:
    user_attempts_df[column] = pd.to_datetime(user_attempts_df[column])

# %%
# Mengecek kembali struktur datanya
user_attempts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2053 entries, 0 to 2052
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2053 non-null   object
#  1   user_id        2053 non-null   object
#  2   assessment_id  2053 non-null   object
#  3   score          2053 non-null   float64
#  4   completed_at   2053 non-null   object
#  5   created_at     2053 non-null   datetime64[ns]
#  6   updated_at     2053 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 112.4+ KB

# %% [markdown]
# **Insights:**
# - Sekarang 2 kolom date sudah sesuai tipe datanya

# %%
# Mengecek deskriptif statistiknya
user_attempts_df.describe(include='all')
# Out:
#              id user_id assessment_id        score         completed_at  \
# count      2053    2053          2053  2053.000000                 2053
# unique     2000     873           200          NaN                 1927
# top     UA01001   S0128       AS00169          NaN  2026-04-27 23:18:52
# freq          2       8            24          NaN                  124
# mean        NaN     NaN           NaN    53.983176                  NaN
# min         NaN     NaN           NaN   -50.000000                  NaN
# 25%         NaN     NaN           NaN    25.420000                  NaN
# 50%         NaN     NaN           NaN    49.020000                  NaN
# 75%         NaN     NaN           NaN    73.790000                  NaN
# max         NaN     NaN           NaN   999.000000                  NaN
# std         NaN     NaN           NaN    75.231112                  NaN
#
#                            created_at                     updated_at
# count                            2053                           2053
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean    2026-04-23 04:06:16.173891840  2026-04-23 04:50:35.395518976
# min               2026-03-03 10:11:37            2026-03-03 10:57:37
# 25%               2026-04-22 01:09:36            2026-04-22 01:55:36
# 50%               2026-04-26 02:07:18            2026-04-26 02:53:18
# 75%               2026-04-27 13:05:08            2026-04-27 13:51:08
# max               2026-04-27 23:18:45            2026-04-27 23:18:52
# std                               NaN                            NaN

# %% [markdown]
# **Insights:**
# - Pada kolom score, terdapat invalid value
# - Nilai minimumnya 50, sedangkan nilai nilai maxnya 999. Hal ini perlu ditangani

# %% [markdown]
# **Insights:**
# - Pada kolom score, terdapat invalid value
# - Nilai minimumnya 50, sedangkan nilai nilai maxnya 999. Hal ini perlu ditangani

# %%
# Cek baris nilai yang di bawah 0 atau di atas 100
filter_score_negative = user_attempts_df['score'] < 0 
filter_score_invalid_positif = user_attempts_df['score'] > 100 # Filter data yang nilai nya > 100 
user_attempts_df[filter_score_negative | filter_score_invalid_positif]
# Out:
#            id user_id assessment_id  score         completed_at  \
# 16    UA00016   S0849       AS00133  -50.0  2026-04-25 17:05:44
# 21    UA00021   S0371       AS00080  -50.0  2026-04-27 16:34:31
# 97    UA00097   S0684       AS00036  -50.0  2026-04-27 10:48:42
# 276   UA00267   S0428       AS00080  999.0  2026-04-14 01:03:41
# 303   UA00294   S0385       AS00084  999.0  2026-04-23 01:20:16
# 431   UA00418   S0655       AS00089  999.0  2026-04-26 20:30:30
# 503   UA00487   S0501       AS00062  999.0  2026-04-27 15:12:45
# 641   UA00621   S0998       AS00167  999.0  2026-04-27 07:26:40
# 668   UA00648   S0413       AS00039  -50.0  2026-04-27 08:46:22
# 946   UA00917   S0123       AS00038  -50.0  2026-04-25 10:09:06
# 954   UA00925   S0821       AS00069  999.0  2026-04-27 21:32:34
# 1192  UA01156   S0356       AS00123  999.0  2026-04-24 00:04:42
# 1198  UA01162   S0904       AS00152  -50.0  2026-03-28 04:01:32
# 1303  UA01265   S0428       AS00008  -50.0  2026-04-25 23:53:29
# 1349  UA01310   S0326       AS00197  -50.0  2026-04-24 15:06:44
# 1467  UA01425   S0233       AS00169  999.0  2026-04-24 17:56:13
# 1468  UA01425   S0233       AS00169  999.0  2026-04-26 10:13:42
# 1512  UA01467   S0169       AS00055  999.0  2026-04-20 13:50:44
# 1554  UA01508   S0601       AS00089  999.0  2026-04-25 13:38:12
# 1661  UA01614   S0810       AS00167  -50.0  2026-04-27 06:18:19
# 1770  UA01721   S0990       AS00074  -50.0  2026-04-27 08:52:51
#
#               created_at          updated_at
# 16   2026-04-25 16:23:44 2026-04-25 17:09:44
# 21   2026-04-27 15:52:31 2026-04-27 16:38:31
# 97   2026-04-27 10:06:42 2026-04-27 10:52:42
# 276  2026-04-14 00:21:41 2026-04-14 01:07:41
# 303  2026-04-23 00:38:16 2026-04-23 01:24:16
# 431  2026-04-26 19:48:30 2026-04-26 20:34:30
# 503  2026-04-27 14:30:45 2026-04-27 15:16:45
# 641  2026-04-27 06:44:40 2026-04-27 07:30:40
# 668  2026-04-27 08:04:22 2026-04-27 08:50:22
# 946  2026-04-25 09:27:06 2026-04-25 10:13:06
# 954  2026-04-27 20:50:34 2026-04-27 21:36:34
# 1192 2026-04-23 23:22:42 2026-04-24 00:08:42
# 1198 2026-03-28 03:19:32 2026-03-28 04:05:32
# 1303 2026-04-25 23:11:29 2026-04-25 23:57:29
# 1349 2026-04-24 14:24:44 2026-04-24 15:10:44
# 1467 2026-04-24 17:14:13 2026-04-24 18:00:13
# 1468 2026-04-26 09:31:42 2026-04-26 10:17:42
# 1512 2026-04-20 13:08:44 2026-04-20 13:54:44
# 1554 2026-04-25 12:56:12 2026-04-25 13:42:12
# 1661 2026-04-27 05:36:19 2026-04-27 06:22:19
# 1770 2026-04-27 08:10:51 2026-04-27 08:56:51

# %% [markdown]
# **Insights:**
# - Untuk data skor yang -50, kemungkinan ini kesalahan sistem. Hal ini akan dihandling dengan mengalikan minus 1 ke setiap barisnya yang memiliki skor 50. Sehingga nilainya akan valid
# - Untuk data yang 999, kita akan handle dengan mengisi nilai rata-ratanya

# %%
# Mengisi nilai skor < 0
user_attempts_df.loc[filter_score_negative,'score'] = user_attempts_df.loc[
    filter_score_negative,'score'
].fillna(user_attempts_df.loc[filter_score_negative, 'score'] * (-1), inplace=True)

# %%
# Mengecek apakah nilai yang -50 udah menjadi 50
user_attempts_df[user_attempts_df['score'] < 0]
# Out:
# Empty DataFrame
# Columns: [id, user_id, assessment_id, score, completed_at, created_at, updated_at]
# Index: []

# %% [markdown]
# **Insights:**
# - Untuk data skor yang -50, sekarang sudah tidak ada. Artinya sudah valid nilai minimumnya

# %%
# Mengisi nilai skor > 100 dengan mean
mean = user_attempts_df['score'].mean()
user_attempts_df.loc[filter_score_invalid_positif, 'score'] = user_attempts_df.loc[
    filter_score_invalid_positif, 'score'
].fillna(mean, inplace=True)

# %%
# Mengecek kembali deksriptif statistiknya
user_attempts_df.describe(include='all')
# Out:
#              id user_id assessment_id        score         completed_at  \
# count      2053    2053          2053  2032.000000                 2053
# unique     2000     873           200          NaN                 1927
# top     UA01001   S0128       AS00169          NaN  2026-04-27 23:18:52
# freq          2       8            24          NaN                  124
# mean        NaN     NaN           NaN    49.379163                  NaN
# min         NaN     NaN           NaN     0.020000                  NaN
# 25%         NaN     NaN           NaN    25.505000                  NaN
# 50%         NaN     NaN           NaN    48.990000                  NaN
# 75%         NaN     NaN           NaN    73.602500                  NaN
# max         NaN     NaN           NaN    99.850000                  NaN
# std         NaN     NaN           NaN    28.406938                  NaN
#
#                            created_at                     updated_at
# count                            2053                           2053
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean    2026-04-23 04:06:16.173891840  2026-04-23 04:50:35.395518976
# min               2026-03-03 10:11:37            2026-03-03 10:57:37
# 25%               2026-04-22 01:09:36            2026-04-22 01:55:36
# 50%               2026-04-26 02:07:18            2026-04-26 02:53:18
# 75%               2026-04-27 13:05:08            2026-04-27 13:51:08
# max               2026-04-27 23:18:45            2026-04-27 23:18:52
# std                               NaN                            NaN

# %% [markdown]
# **Insights:**
# - Sekarang, data score sudah valid nilainya
# - Artinya data ini sudah bersih

# %% [markdown]
# `#### Fixing user_progress_df problem

# %%
# Mengecek struktur data
user_progress_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1552 non-null   object
#  1   user_id           1552 non-null   object
#  2   subchapter_id     1552 non-null   object
#  3   chapter_taken_id  1552 non-null   object
#  4   current_level     1476 non-null   object
#  5   status            1552 non-null   object
#  6   created_at        1552 non-null   object
#  7   updated_at        1552 non-null   object
# dtypes: object(8)
# memory usage: 97.1+ KB

# %% [markdown]
# **Insights:**
# - Kita akan mengubah tipe data created_at dan updated_at menjadi datetime
# - Lalu kita juga akan handle missing value dari current_level dengan cara imputation

# %%
# Mengubah tipe data pada kolom created_at dan updated_at dengan memanfaatkan variabel datetime_columns
for column in datetime_columns:
    user_progress_df[column] = pd.to_datetime(user_progress_df[column])

# %%
# Mengecek kembali struktur datanya
user_progress_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1552 non-null   object
#  1   user_id           1552 non-null   object
#  2   subchapter_id     1552 non-null   object
#  3   chapter_taken_id  1552 non-null   object
#  4   current_level     1476 non-null   object
#  5   status            1552 non-null   object
#  6   created_at        1552 non-null   datetime64[ns]
#  7   updated_at        1552 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(6)
# memory usage: 97.1+ KB

# %%
# Mengecek baris data yang memiliki nilai NaN pada kolom current level
filter_curr_level_null = user_progress_df['current_level'].isna()
user_progress_df[filter_curr_level_null]
# Out:
#            id user_id subchapter_id chapter_taken_id current_level  \
# 21    UP00021   S0760      SCT00008         CHT00958           NaN
# 23    UP00023   S0767      SCT00013         CHT00551           NaN
# 24    UP00024   S0109      SCT00008         CHT00702           NaN
# 68    UP00066   S0677      SCT00010         CHT00163           NaN
# 139   UP00132   S0137      SCT00004         CHT00047           NaN
# ...       ...     ...           ...              ...           ...
# 1474  UP01426   S0087      SCT00017         CHT00491           NaN
# 1484  UP01436   S0806      SCT00006         CHT00079           NaN
# 1495  UP01447   S0213      SCT00018         CHT01085           NaN
# 1526  UP01476   S0291      SCT00010         CHT00270           NaN
# 1534  UP01484   S0018      SCT00001         CHT00539           NaN
#
#            status          created_at          updated_at
# 21           done 2026-03-22 18:05:44 2026-03-23 18:22:44
# 23    in-progress 2026-04-22 14:09:23 2026-04-23 14:26:23
# 24    in progress 2026-03-20 03:16:14 2026-03-21 03:33:14
# 68    in progress 2026-04-12 03:28:24 2026-04-13 03:45:24
# 139   not started 2026-04-18 14:14:31 2026-04-19 14:31:31
# ...           ...                 ...                 ...
# 1474  in progress 2026-04-26 21:13:42 2026-04-27 21:30:42
# 1484  in progress 2026-03-29 13:42:43 2026-03-30 13:59:43
# 1495  not started 2026-04-24 20:14:24 2026-04-25 20:31:24
# 1526  not started 2026-04-27 20:26:44 2026-04-27 23:18:52
# 1534  in progress 2026-04-20 06:30:19 2026-04-21 06:47:19
#
# [76 rows x 8 columns]

# %%
# Mendefinisikan nilai mode current_level
mode_current_level = user_progress_df['current_level'].mode().values[0]
print(f'Nilai mode (modus) untuk current_level saat ini: {mode_current_level}')
# Out:
# Nilai mode (modus) untuk current_level saat ini: advanced

# %%
# Mengisi nilai NaN pada kolom current_level dengan nilai mode_current_level
user_progress_df['current_level'].fillna(mode_current_level, inplace=True)
# Out:
# C:\Users\Hype AMD\AppData\Local\Temp\ipykernel_29924\2365380606.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   user_progress_df['current_level'].fillna(mode_current_level, inplace=True)

# %%
# Melihat perbedaan separator pada kolom status untuk in-progress
user_progress_df[user_progress_df['status'] == 'in progress']
# Out:
#            id user_id subchapter_id chapter_taken_id current_level  \
# 7     UP00007   S0759      SCT00001         CHT00839      beginner
# 11    UP00011   S0423      SCT00017         CHT00440  intermediate
# 12    UP00012   S0072      SCT00001         CHT00701      advanced
# 15    UP00015   S0133      SCT00021         CHT00173      beginner
# 17    UP00017   S0067      SCT00012         CHT01104      beginner
# ...       ...     ...           ...              ...           ...
# 1541  UP01491   S0133      SCT00004         CHT00591      beginner
# 1547  UP01497   S0568      SCT00018         CHT00713  intermediate
# 1549  UP01499   S0584      SCT00002         CHT01105  intermediate
# 1550  UP01500   S0707      SCT00002         CHT00120      beginner
# 1551  UP01500   S0707      SCT00002         CHT00120      beginner
#
#            status          created_at          updated_at
# 7     in progress 2026-04-27 18:10:29 2026-04-27 23:18:52
# 11    in progress 2026-04-14 23:18:53 2026-04-15 23:35:53
# 12    in progress 2026-04-20 05:19:43 2026-04-21 05:36:43
# 15    in progress 2026-04-18 14:18:24 2026-04-19 14:35:24
# 17    in progress 2026-04-25 14:05:21 2026-04-26 14:22:21
# ...           ...                 ...                 ...
# 1541  in progress 2026-02-28 09:57:19 2026-03-01 10:14:19
# 1547  in progress 2026-03-13 14:28:55 2026-03-14 14:45:55
# 1549  in progress 2026-04-16 23:52:24 2026-04-18 00:09:24
# 1550  in progress 2026-04-20 10:21:57 2026-04-21 10:38:57
# 1551  in progress 2026-04-26 13:07:25 2026-04-27 13:24:25
#
# [484 rows x 8 columns]

# %%
# Mengganti separator whitespace pada in progress menjadi in-progress
# user_progress_df[user_progress_df['status'] == 'in progress'].replace({'in progress': 'in-progress'}, inplace=True)
user_progress_df.loc[(user_progress_df['status'] == 'in progress'), 'status'] = 'in-progress'

# %%
# Mengecek kembali apakah masih ada separator whitespace pada status in progress
user_progress_df[user_progress_df['status'] == 'in progress']
# Out:
# Empty DataFrame
# Columns: [id, user_id, subchapter_id, chapter_taken_id, current_level, status, created_at, updated_at]
# Index: []

# %% [markdown]
# **Insights:**
# - Sekarang sudah tidak inconsistent value pada kolom status

# %%
# Mengecek kembali struktur datanya
user_progress_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1552 non-null   object
#  1   user_id           1552 non-null   object
#  2   subchapter_id     1552 non-null   object
#  3   chapter_taken_id  1552 non-null   object
#  4   current_level     1552 non-null   object
#  5   status            1552 non-null   object
#  6   created_at        1552 non-null   datetime64[ns]
#  7   updated_at        1552 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(6)
# memory usage: 97.1+ KB

# %% [markdown]
# **Insights:**
# - Sekarang sudah tidak ada missing value di setiap kolom
# - Tipe data kolom date juga sudah sesuai
# - Artinya data ini sudah bersih

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Explore user_attempts_df, assessments_df, chapters_taken_df, dan chapters_df

# %%
# Rename kolom yang berpotensi bentrok nama nya pada user_attempts_df dan assessments_df
user_attempts_clean_df = user_attempts_df.rename(columns={
    'id': 'attempt_id',
    'created_at': 'attempt_created_at',
    'updated_at': 'attempt_updated_at'
})

assessments_clean_df = assessments_df.rename(columns={
    'id': 'assessment_id', 
    'created_at': 'assessment_created_at',
    'updated_at': 'assessment_updated_at'
})

# %%
# Rename kolom yang berpotensi bentrok nama nya pada chapters_taken_df dan chapters_df
chapters_taken_clean_df = chapters_taken_df.rename(columns={
    'id': 'chapter_taken_id',
    'created_at': 'chapter_taken_created_at',
    'updated_at': 'chapter_taken_updated_at'
})

chapters_clean_df = chapters_df.rename(columns={
    'id': 'chapter_id', 
    'created_at': 'chapter_created_at',
    'updated_at': 'chapter_updated_at'
})

# %%
# Merge dataframe user_attempts_df dan assessments_df 
attempts_assessments_join_df = pd.merge(
    left=user_attempts_clean_df,
    right=assessments_clean_df,
    how='left',
    left_on='assessment_id',
    right_on='assessment_id'
)
attempts_assessments_join_df.head()
# Out:
#   attempt_id user_id assessment_id  score         completed_at  \
# 0    UA00001   S9999       AS00193  34.80  2026-04-20 21:50:12
# 1    UA00002   S0180       AS00112  56.55  2026-04-25 09:26:43
# 2    UA00003   S0362       AS00056  86.55  2026-04-27 06:19:37
# 3    UA00004   S0702       AS00180  14.12  2026-04-27 23:18:52
# 4    UA00005   S0585       AS00153   8.11  2026-04-27 21:36:30
#
#    attempt_created_at  attempt_updated_at chapter_taken_id subchapter_id  \
# 0 2026-04-20 21:08:12 2026-04-20 21:54:12         CHT00476      SCT00014
# 1 2026-04-25 08:44:43 2026-04-25 09:30:43         CHT00659      SCT00005
# 2 2026-04-27 05:37:37 2026-04-27 06:23:37         CHT00053      SCT00020
# 3 2026-04-27 23:04:12 2026-04-27 23:18:52         CHT00456      SCT00021
# 4 2026-04-27 20:54:30 2026-04-27 21:40:30         CHT00202      SCT00005
#
#             title       type  correct_answer assessment_created_at  \
# 0  Assessment 193  placement            13.0   2026-04-17 05:34:22
# 1  Assessment 112  placement            16.0   2026-04-21 20:53:01
# 2   Assessment 56       quiz             7.0   2026-04-22 15:29:22
# 3  Assessment 180  placement            14.0   2026-04-27 16:41:11
# 4  Assessment 153       exam             8.0   2026-04-27 15:25:15
#
#   assessment_updated_at
# 0   2026-04-17 06:21:22
# 1   2026-04-21 21:40:01
# 2   2026-04-22 16:16:22
# 3   2026-04-27 17:28:11
# 4   2026-04-27 16:12:15

# %%
# Mengecek struktur data
attempts_assessments_join_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2159 entries, 0 to 2158
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   attempt_id             2159 non-null   object
#  1   user_id                2159 non-null   object
#  2   assessment_id          2159 non-null   object
#  3   score                  2136 non-null   float64
#  4   completed_at           2159 non-null   object
#  5   attempt_created_at     2159 non-null   datetime64[ns]
#  6   attempt_updated_at     2159 non-null   datetime64[ns]
#  7   chapter_taken_id       2159 non-null   object
#  8   subchapter_id          2159 non-null   object
#  9   title                  2159 non-null   object
#  10  type                   2159 non-null   object
#  11  correct_answer         2159 non-null   float64
#  12  assessment_created_at  2159 non-null   datetime64[ns]
#  13  assessment_updated_at  2159 non-null   datetime64[ns]
# dtypes: datetime64[ns](4), float64(2), object(8)
# memory usage: 236.3+ KB

# %%
# Merge dataframe chapters_taken_df dan chapters_df 
chapters_taken_join_df = pd.merge(
    left=chapters_taken_clean_df,
    right=chapters_clean_df,
    how='left',
    left_on='chapter_id',
    right_on='chapter_id'
)
chapters_taken_join_df.head()
# Out:
#   chapter_taken_id user_id chapter_id chapter_taken_updated_at  \
# 0         CHT00001   S0331    CT00002      2026-04-27 23:18:52
# 1         CHT00002   S0242    CT00002      2026-04-06 12:52:29
# 2         CHT00003   S0181    CT00006      2026-04-12 00:35:07
# 3         CHT00004   S0145    CT00003      2026-04-27 23:18:52
# 4         CHT00005   S0116    CT00006      2026-04-20 18:32:43
#
#   chapter_taken_created_at               name  total_subchapter  \
# 0      2026-04-25 03:10:15  Bilangan Rasional                 3
# 1      2026-04-01 19:01:29  Bilangan Rasional                 3
# 2      2026-04-07 06:44:07   Data dan Diagram                 6
# 3      2026-04-26 22:45:20              Rasio                 3
# 4      2026-04-16 00:41:43   Data dan Diagram                 6
#
#   chapter_created_at chapter_updated_at
# 0         2026-01-01         2026-01-01
# 1         2026-01-01         2026-01-01
# 2         2026-01-01         2026-01-01
# 3         2026-01-01         2026-01-01
# 4         2026-01-01         2026-01-01

# %%
# Mengecek struktur data
chapters_taken_join_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   chapter_taken_id          1220 non-null   object
#  1   user_id                   1220 non-null   object
#  2   chapter_id                1220 non-null   object
#  3   chapter_taken_updated_at  1220 non-null   datetime64[ns]
#  4   chapter_taken_created_at  1220 non-null   datetime64[ns]
#  5   name                      1220 non-null   object
#  6   total_subchapter          1220 non-null   int64
#  7   chapter_created_at        1220 non-null   datetime64[ns]
#  8   chapter_updated_at        1220 non-null   datetime64[ns]
# dtypes: datetime64[ns](4), int64(1), object(4)
# memory usage: 85.9+ KB

# %%
# Merge dataframe untuk menjawab pertanyaan 1
answer_q1_df = pd.merge(
    left=attempts_assessments_join_df,
    right=chapters_taken_join_df,
    how='left',
    left_on='chapter_taken_id',
    right_on='chapter_taken_id'
)
answer_q1_df.head()
# Out:
#   attempt_id user_id_x assessment_id  score         completed_at  \
# 0    UA00001     S9999       AS00193  34.80  2026-04-20 21:50:12
# 1    UA00002     S0180       AS00112  56.55  2026-04-25 09:26:43
# 2    UA00003     S0362       AS00056  86.55  2026-04-27 06:19:37
# 3    UA00004     S0702       AS00180  14.12  2026-04-27 23:18:52
# 4    UA00005     S0585       AS00153   8.11  2026-04-27 21:36:30
#
#    attempt_created_at  attempt_updated_at chapter_taken_id subchapter_id  \
# 0 2026-04-20 21:08:12 2026-04-20 21:54:12         CHT00476      SCT00014
# 1 2026-04-25 08:44:43 2026-04-25 09:30:43         CHT00659      SCT00005
# 2 2026-04-27 05:37:37 2026-04-27 06:23:37         CHT00053      SCT00020
# 3 2026-04-27 23:04:12 2026-04-27 23:18:52         CHT00456      SCT00021
# 4 2026-04-27 20:54:30 2026-04-27 21:40:30         CHT00202      SCT00005
#
#             title  ... assessment_created_at  assessment_updated_at user_id_y  \
# 0  Assessment 193  ...   2026-04-17 05:34:22    2026-04-17 06:21:22     S0608
# 1  Assessment 112  ...   2026-04-21 20:53:01    2026-04-21 21:40:01     S0150
# 2   Assessment 56  ...   2026-04-22 15:29:22    2026-04-22 16:16:22     S0176
# 3  Assessment 180  ...   2026-04-27 16:41:11    2026-04-27 17:28:11     S0160
# 4  Assessment 153  ...   2026-04-27 15:25:15    2026-04-27 16:12:15     S0823
#
#   chapter_id chapter_taken_updated_at chapter_taken_created_at  \
# 0    CT00002      2026-04-18 14:58:05      2026-04-13 21:07:05
# 1    CT00006      2026-04-25 09:05:14      2026-04-20 15:14:14
# 2    CT00006      2026-04-27 06:19:28      2026-04-22 12:28:28
# 3    CT00004      2026-04-27 23:18:52      2026-04-27 02:35:39
# 4    CT00006      2026-04-27 23:18:52      2026-04-27 03:12:02
#
#                 name total_subchapter chapter_created_at  chapter_updated_at
# 0  Bilangan Rasional                3         2026-01-01          2026-01-01
# 1   Data dan Diagram                6         2026-01-01          2026-01-01
# 2   Data dan Diagram                6         2026-01-01          2026-01-01
# 3     Bentuk Aljabar                3         2026-01-01          2026-01-01
# 4   Data dan Diagram                6         2026-01-01          2026-01-01
#
# [5 rows x 22 columns]

# %%
# Mengecek struktur datanya
answer_q1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2371 entries, 0 to 2370
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   attempt_id                2371 non-null   object
#  1   user_id_x                 2371 non-null   object
#  2   assessment_id             2371 non-null   object
#  3   score                     2344 non-null   float64
#  4   completed_at              2371 non-null   object
#  5   attempt_created_at        2371 non-null   datetime64[ns]
#  6   attempt_updated_at        2371 non-null   datetime64[ns]
#  7   chapter_taken_id          2371 non-null   object
#  8   subchapter_id             2371 non-null   object
#  9   title                     2371 non-null   object
#  10  type                      2371 non-null   object
#  11  correct_answer            2371 non-null   float64
#  12  assessment_created_at     2371 non-null   datetime64[ns]
#  13  assessment_updated_at     2371 non-null   datetime64[ns]
#  14  user_id_y                 2371 non-null   object
#  15  chapter_id                2371 non-null   object
#  16  chapter_taken_updated_at  2371 non-null   datetime64[ns]
#  17  chapter_taken_created_at  2371 non-null   datetime64[ns]
#  18  name                      2371 non-null   object
#  19  total_subchapter          2371 non-null   int64
#  20  chapter_created_at        2371 non-null   datetime64[ns]
#  21  chapter_updated_at        2371 non-null   datetime64[ns]
# dtypes: datetime64[ns](8), float64(2), int64(1), object(11)
# memory usage: 407.6+ KB

# %%
# Melihat bab mana yang memiliki rata-rata skor terendah
groupby_chapter = answer_q1_df.groupby(by='name')['score'].mean().reset_index()
groupby_chapter
# Out:
#                 name      score
# 0     Bentuk Aljabar  51.010430
# 1     Bilangan Bulat  50.263360
# 2  Bilangan Rasional  50.494080
# 3   Data dan Diagram  51.515012
# 4       Kesebangunan  47.805468
# 5              Rasio  45.806348

# %%
# Mengurutkan bab dari yang paling terkecil
groupby_chapter = groupby_chapter.sort_values(by='score', ascending=True, ignore_index=True)
groupby_chapter.columns = ['chapter_name', 'mean_score']
groupby_chapter
# Out:
#         chapter_name  mean_score
# 0              Rasio   45.806348
# 1       Kesebangunan   47.805468
# 2     Bilangan Bulat   50.263360
# 3  Bilangan Rasional   50.494080
# 4     Bentuk Aljabar   51.010430
# 5   Data dan Diagram   51.515012

# %% [markdown]
# ### Explore user_progress_df, subchapters_df

# %%
# Rename kolom yang berpotensi bentrok nama nya pada user_progress_df dan subchapters_df
user_progress_clean_df = user_progress_df.rename(columns={
    'id': 'user_progress_id',
    'created_at': 'user_progress_created_at',
    'updated_at': 'user_progress_updated_at'
})

subchapters_clean_df = subchapters_df.rename(columns={
    'id': 'subchapter_id', 
    'created_at': 'subchapter_created_at',
    'updated_at': 'subchapter_updated_at'
})

# %%
# Merge dataframe user_progress_df dan subchapters_df 
progress_subchapters_join_df = pd.merge(
    left=user_progress_clean_df,
    right=subchapters_clean_df,
    how='left',
    left_on='subchapter_id',
    right_on='subchapter_id',
)
progress_subchapters_join_df.head()
# Out:
#   user_progress_id user_id subchapter_id chapter_taken_id current_level  \
# 0          UP00001   S0591      SCT00017         CHT00802      beginner
# 1          UP00002   S0655      SCT00020         CHT00317      beginner
# 2          UP00002   S0655      SCT00020         CHT00317      beginner
# 3          UP00003   S0617      SCT00008         CHT00533  intermediate
# 4          UP00004   S0966      SCT00001         CHT00638  intermediate
#
#         status user_progress_created_at user_progress_updated_at chapter_id  \
# 0  not started      2026-04-19 01:10:42      2026-04-20 01:27:42    CT00006
# 1         done      2026-04-22 08:32:30      2026-04-23 08:49:30    CT00006
# 2         done      2026-04-24 17:35:18      2026-04-25 17:52:18    CT00006
# 3  not started      2026-04-25 18:53:39      2026-04-26 19:10:39    CT00003
# 4         done      2026-04-19 00:35:00      2026-04-20 00:52:00    CT00001
#
#                       name subchapter_created_at subchapter_updated_at
# 0         Macam-Macam Data            2026-01-01            2026-01-01
# 1        Diagram Lingkaran            2026-01-01            2026-01-01
# 2        Diagram Lingkaran            2026-01-01            2026-01-01
# 3                    Skala            2026-01-01            2026-01-01
# 4  Memahami Bilangan Bulat            2026-01-01            2026-01-01

# %%
# Mengecek struktur data
progress_subchapters_join_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   user_progress_id          1552 non-null   object
#  1   user_id                   1552 non-null   object
#  2   subchapter_id             1552 non-null   object
#  3   chapter_taken_id          1552 non-null   object
#  4   current_level             1552 non-null   object
#  5   status                    1552 non-null   object
#  6   user_progress_created_at  1552 non-null   datetime64[ns]
#  7   user_progress_updated_at  1552 non-null   datetime64[ns]
#  8   chapter_id                1552 non-null   object
#  9   name                      1552 non-null   object
#  10  subchapter_created_at     1552 non-null   datetime64[ns]
#  11  subchapter_updated_at     1552 non-null   datetime64[ns]
# dtypes: datetime64[ns](4), object(8)
# memory usage: 145.6+ KB

# %%
# Menghitung persentase distribusi current_level siswa pada seluruh subbab
rows_total = progress_subchapters_join_df.shape[0]
groupby_current_level = progress_subchapters_join_df.groupby(by='current_level')['user_progress_id'].agg(
    lambda x: ((x.count() / rows_total) * 100).__round__(2)
).reset_index()
groupby_current_level.columns = ['current_level', 'percentage']
groupby_current_level
# Out:
#   current_level  percentage
# 0      advanced       37.44
# 1      beginner       31.31
# 2  intermediate       31.25

# %% [markdown]
# ### Explore user_progress_df, chapters_taken_df, dan chapters_df

# %%
# Merge dataset user_progress_df dan chapters_taken_df
progress_chapters_taken_join_df = pd.merge(
    left=user_progress_clean_df,
    right=chapters_taken_clean_df,
    how='left',
    left_on='chapter_taken_id',
    right_on='chapter_taken_id',
)
progress_chapters_taken_join_df.head()
# Out:
#   user_progress_id user_id_x subchapter_id chapter_taken_id current_level  \
# 0          UP00001     S0591      SCT00017         CHT00802      beginner
# 1          UP00002     S0655      SCT00020         CHT00317      beginner
# 2          UP00002     S0655      SCT00020         CHT00317      beginner
# 3          UP00002     S0655      SCT00020         CHT00317      beginner
# 4          UP00002     S0655      SCT00020         CHT00317      beginner
#
#         status user_progress_created_at user_progress_updated_at user_id_y  \
# 0  not started      2026-04-19 01:10:42      2026-04-20 01:27:42     S0559
# 1         done      2026-04-22 08:32:30      2026-04-23 08:49:30     S0724
# 2         done      2026-04-22 08:32:30      2026-04-23 08:49:30     S0724
# 3         done      2026-04-24 17:35:18      2026-04-25 17:52:18     S0724
# 4         done      2026-04-24 17:35:18      2026-04-25 17:52:18     S0724
#
#   chapter_id chapter_taken_updated_at chapter_taken_created_at
# 0    CT00006      2026-04-16 09:54:40      2026-04-11 16:03:40
# 1    CT00003      2026-04-15 10:03:08      2026-04-10 16:12:08
# 2    CT00003      2026-04-13 08:04:38      2026-04-08 14:13:38
# 3    CT00003      2026-04-15 10:03:08      2026-04-10 16:12:08
# 4    CT00003      2026-04-13 08:04:38      2026-04-08 14:13:38

# %%
# Merge progress_chapters_taken_join_df dan chapters_clean_df
progress_chapters_join_df = pd.merge(
    left=progress_chapters_taken_join_df,
    right=chapters_clean_df,
    how='left',
    left_on='chapter_id',
    right_on='chapter_id'
)
progress_chapters_join_df.head()
# Out:
#   user_progress_id user_id_x subchapter_id chapter_taken_id current_level  \
# 0          UP00001     S0591      SCT00017         CHT00802      beginner
# 1          UP00002     S0655      SCT00020         CHT00317      beginner
# 2          UP00002     S0655      SCT00020         CHT00317      beginner
# 3          UP00002     S0655      SCT00020         CHT00317      beginner
# 4          UP00002     S0655      SCT00020         CHT00317      beginner
#
#         status user_progress_created_at user_progress_updated_at user_id_y  \
# 0  not started      2026-04-19 01:10:42      2026-04-20 01:27:42     S0559
# 1         done      2026-04-22 08:32:30      2026-04-23 08:49:30     S0724
# 2         done      2026-04-22 08:32:30      2026-04-23 08:49:30     S0724
# 3         done      2026-04-24 17:35:18      2026-04-25 17:52:18     S0724
# 4         done      2026-04-24 17:35:18      2026-04-25 17:52:18     S0724
#
#   chapter_id chapter_taken_updated_at chapter_taken_created_at  \
# 0    CT00006      2026-04-16 09:54:40      2026-04-11 16:03:40
# 1    CT00003      2026-04-15 10:03:08      2026-04-10 16:12:08
# 2    CT00003      2026-04-13 08:04:38      2026-04-08 14:13:38
# 3    CT00003      2026-04-15 10:03:08      2026-04-10 16:12:08
# 4    CT00003      2026-04-13 08:04:38      2026-04-08 14:13:38
#
#                name  total_subchapter chapter_created_at chapter_updated_at
# 0  Data dan Diagram                 6         2026-01-01         2026-01-01
# 1             Rasio                 3         2026-01-01         2026-01-01
# 2             Rasio                 3         2026-01-01         2026-01-01
# 3             Rasio                 3         2026-01-01         2026-01-01
# 4             Rasio                 3         2026-01-01         2026-01-01

# %%
# Filter hanya status yang done untuk yang telah diambil
filter_status_chapter_done = progress_chapters_join_df[progress_chapters_join_df['status'] == 'done']
groupby_status_chapter = filter_status_chapter_done.groupby(by=['name', 'status'])['user_progress_id'].count().reset_index()
groupby_status_chapter.columns = ['chapter_name', 'status', 'count_done_status']
groupby_status_chapter
# Out:
#         chapter_name status  count_done_status
# 0     Bentuk Aljabar   done                100
# 1     Bilangan Bulat   done                 77
# 2  Bilangan Rasional   done                 68
# 3   Data dan Diagram   done                 89
# 4       Kesebangunan   done                 85
# 5              Rasio   done                 81

# %% [markdown]
# ### Exlore user_progress_df dan subchapters_df

# %%
# Menggunakan kembali progress_subchapters_join_df dan melihat isi datanya
progress_subchapters_join_df.head()
# Out:
#   user_progress_id user_id subchapter_id chapter_taken_id current_level  \
# 0          UP00001   S0591      SCT00017         CHT00802      beginner
# 1          UP00002   S0655      SCT00020         CHT00317      beginner
# 2          UP00002   S0655      SCT00020         CHT00317      beginner
# 3          UP00003   S0617      SCT00008         CHT00533  intermediate
# 4          UP00004   S0966      SCT00001         CHT00638  intermediate
#
#         status user_progress_created_at user_progress_updated_at chapter_id  \
# 0  not started      2026-04-19 01:10:42      2026-04-20 01:27:42    CT00006
# 1         done      2026-04-22 08:32:30      2026-04-23 08:49:30    CT00006
# 2         done      2026-04-24 17:35:18      2026-04-25 17:52:18    CT00006
# 3  not started      2026-04-25 18:53:39      2026-04-26 19:10:39    CT00003
# 4         done      2026-04-19 00:35:00      2026-04-20 00:52:00    CT00001
#
#                       name subchapter_created_at subchapter_updated_at
# 0         Macam-Macam Data            2026-01-01            2026-01-01
# 1        Diagram Lingkaran            2026-01-01            2026-01-01
# 2        Diagram Lingkaran            2026-01-01            2026-01-01
# 3                    Skala            2026-01-01            2026-01-01
# 4  Memahami Bilangan Bulat            2026-01-01            2026-01-01

# %%
# Menghitung selisih antara created_at dengan updated_at user progress dan memfilter status subchapter in-progress dan 
progress_subchapters_join_df['diff_progress_minutes'] = ((progress_subchapters_join_df['user_progress_updated_at'] - progress_subchapters_join_df['user_progress_created_at']).dt.total_seconds() / 60).round(0)
filter_status_chapter_inprogress = progress_subchapters_join_df[(progress_subchapters_join_df['status'] == 'in-progress')]

# %%
# Mengecek Struktur Data
progress_subchapters_join_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   user_progress_id          1552 non-null   object
#  1   user_id                   1552 non-null   object
#  2   subchapter_id             1552 non-null   object
#  3   chapter_taken_id          1552 non-null   object
#  4   current_level             1552 non-null   object
#  5   status                    1552 non-null   object
#  6   user_progress_created_at  1552 non-null   datetime64[ns]
#  7   user_progress_updated_at  1552 non-null   datetime64[ns]
#  8   chapter_id                1552 non-null   object
#  9   name                      1552 non-null   object
#  10  subchapter_created_at     1552 non-null   datetime64[ns]
#  11  subchapter_updated_at     1552 non-null   datetime64[ns]
#  12  diff_progress_minutes     1552 non-null   float64
# dtypes: datetime64[ns](4), float64(1), object(8)
# memory usage: 157.8+ KB

# %%
# Melihat kolom baru, yaitu diff_minutes
filter_status_chapter_inprogress.head()
# Out:
#    user_progress_id user_id subchapter_id chapter_taken_id current_level  \
# 7           UP00007   S0759      SCT00001         CHT00839      beginner
# 11          UP00011   S0423      SCT00017         CHT00440  intermediate
# 12          UP00012   S0072      SCT00001         CHT00701      advanced
# 15          UP00015   S0133      SCT00021         CHT00173      beginner
# 17          UP00017   S0067      SCT00012         CHT01104      beginner
#
#          status user_progress_created_at user_progress_updated_at chapter_id  \
# 7   in-progress      2026-04-27 18:10:29      2026-04-27 23:18:52    CT00001
# 11  in-progress      2026-04-14 23:18:53      2026-04-15 23:35:53    CT00006
# 12  in-progress      2026-04-20 05:19:43      2026-04-21 05:36:43    CT00001
# 15  in-progress      2026-04-18 14:18:24      2026-04-19 14:35:24    CT00006
# 17  in-progress      2026-04-25 14:05:21      2026-04-26 14:22:21    CT00004
#
#                                name subchapter_created_at  \
# 7           Memahami Bilangan Bulat            2026-01-01
# 11                 Macam-Macam Data            2026-01-01
# 12          Memahami Bilangan Bulat            2026-01-01
# 15       Memilih Diagram yang Tepat            2026-01-01
# 17  Pemodelan dengan Bentuk Aljabar            2026-01-01
#
#    subchapter_updated_at  diff_progress_minutes
# 7             2026-01-01                  308.0
# 11            2026-01-01                 1457.0
# 12            2026-01-01                 1457.0
# 15            2026-01-01                 1457.0
# 17            2026-01-01                 1457.0

# %%
# Groupby based on subchapter
groupby_subchapter = filter_status_chapter_inprogress.groupby(by='name').agg({
    'user_progress_id': 'nunique',
    'diff_progress_minutes': 'mean'
}).reset_index()

# %%
# Sort values nya secara descending
groupby_subchapter = groupby_subchapter.sort_values(by='diff_progress_minutes', ascending=False)
groupby_subchapter.columns = ['subchapter_name', 'total_user', 'diff_progress_minutes']
groupby_subchapter
# Out:
#                        subchapter_name  total_user  diff_progress_minutes
# 8           Kesebangunan pada Segitiga          22            1428.260870
# 15       Operasi Hitung Bilangan Bulat          25            1413.769231
# 19                               Skala          37            1409.641026
# 11                    Macam-Macam Data          16            1393.187500
# 9                         Konsep Rasio          28            1385.900000
# 4             Diagram dalam Statistika          32            1356.531250
# 16  Operasi Hitung Bilangan Rasional .          30            1354.812500
# 20          Unsur-Unsur Bentuk Aljabar          26            1347.464286
# 14          Memilih Diagram yang Tepat          30            1333.066667
# 6                 Hubungan Antar Sudut          29            1332.137931
# 1         Di Antara Dua Bilangan Bulat          23            1331.695652
# 7               Investigasi Statistika          25            1311.296296
# 17     Pemodelan dengan Bentuk Aljabar          26            1309.846154
# 3                    Diagram Lingkaran          23            1302.375000
# 0                    Arti Kesebangunan          22            1293.181818
# 13     Membandingkan Bilangan Rasional          21            1290.826087
# 10               Laju Perubahan Satuan          21            1286.608696
# 12             Memahami Bilangan Bulat          32            1261.781250
# 18     Sifat-Sifat dan Operasi Aljabar          22            1243.869565
# 5                Faktor Bilangan Bulat          23            1166.956522
# 2                       Diagram Batang          28            1136.586207

# %% [markdown]
# ### Explore assessments_df, user_attempts_df, chapters_taken_df, dan chapters_df

# %%
# answer_q1_df merupakan hasil merge dari semua dataframe ini. Maka akan kita gunakan kembali
answer_q1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2371 entries, 0 to 2370
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   attempt_id                2371 non-null   object
#  1   user_id_x                 2371 non-null   object
#  2   assessment_id             2371 non-null   object
#  3   score                     2344 non-null   float64
#  4   completed_at              2371 non-null   object
#  5   attempt_created_at        2371 non-null   datetime64[ns]
#  6   attempt_updated_at        2371 non-null   datetime64[ns]
#  7   chapter_taken_id          2371 non-null   object
#  8   subchapter_id             2371 non-null   object
#  9   title                     2371 non-null   object
#  10  type                      2371 non-null   object
#  11  correct_answer            2371 non-null   float64
#  12  assessment_created_at     2371 non-null   datetime64[ns]
#  13  assessment_updated_at     2371 non-null   datetime64[ns]
#  14  user_id_y                 2371 non-null   object
#  15  chapter_id                2371 non-null   object
#  16  chapter_taken_updated_at  2371 non-null   datetime64[ns]
#  17  chapter_taken_created_at  2371 non-null   datetime64[ns]
#  18  name                      2371 non-null   object
#  19  total_subchapter          2371 non-null   int64
#  20  chapter_created_at        2371 non-null   datetime64[ns]
#  21  chapter_updated_at        2371 non-null   datetime64[ns]
# dtypes: datetime64[ns](8), float64(2), int64(1), object(11)
# memory usage: 407.6+ KB

# %%
# Melihat baris dari answer_q1_df
answer_q1_df.head()
# Out:
#   attempt_id user_id_x assessment_id  score         completed_at  \
# 0    UA00001     S9999       AS00193  34.80  2026-04-20 21:50:12
# 1    UA00002     S0180       AS00112  56.55  2026-04-25 09:26:43
# 2    UA00003     S0362       AS00056  86.55  2026-04-27 06:19:37
# 3    UA00004     S0702       AS00180  14.12  2026-04-27 23:18:52
# 4    UA00005     S0585       AS00153   8.11  2026-04-27 21:36:30
#
#    attempt_created_at  attempt_updated_at chapter_taken_id subchapter_id  \
# 0 2026-04-20 21:08:12 2026-04-20 21:54:12         CHT00476      SCT00014
# 1 2026-04-25 08:44:43 2026-04-25 09:30:43         CHT00659      SCT00005
# 2 2026-04-27 05:37:37 2026-04-27 06:23:37         CHT00053      SCT00020
# 3 2026-04-27 23:04:12 2026-04-27 23:18:52         CHT00456      SCT00021
# 4 2026-04-27 20:54:30 2026-04-27 21:40:30         CHT00202      SCT00005
#
#             title  ... assessment_created_at  assessment_updated_at user_id_y  \
# 0  Assessment 193  ...   2026-04-17 05:34:22    2026-04-17 06:21:22     S0608
